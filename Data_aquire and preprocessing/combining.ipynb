# %%
import requests
import pandas as pd
import numpy as np
import json as js
import datetime as dt
from datetime import timedelta
import time

# %%
df = pd.read_csv(r"C:\Users\ASUS Zephyrus G15\crypto-prediction\data\coinbase_data.csv")

# %%
df
# Out:
#                         time       low      high      open     close  \
# 0        2022-01-01 00:00:00  0.416200  0.420400  0.416600  0.419200
# 1        2022-01-01 01:00:00  0.419200  0.425000  0.419900  0.421100
# 2        2022-01-01 02:00:00  0.418600  0.422900  0.421100  0.418600
# 3        2022-01-01 03:00:00  0.418500  0.420400  0.418900  0.418600
# 4        2022-01-01 04:00:00  0.417300  0.419700  0.419400  0.418300
# ...                      ...       ...       ...       ...       ...
# 1542016  2022-05-27 12:00:00  0.000128  0.000136  0.000132  0.000131
# 1542017  2022-05-27 13:00:00  0.000122  0.000133  0.000131  0.000127
# 1542018  2022-05-27 14:00:00  0.000118  0.000130  0.000127  0.000128
# 1542019  2022-05-27 15:00:00  0.000114  0.000129  0.000129  0.000121
# 1542020  2022-05-27 16:00:00  0.000123  0.000128  0.000124  0.000126
#
#                volume          id
# 0        2.633730e+04    POWR-USD
# 1        5.698080e+04    POWR-USD
# 2        2.797330e+04    POWR-USD
# 3        2.638640e+04    POWR-USD
# 4        1.690010e+04    POWR-USD
# ...               ...         ...
# 1542016  7.154788e+08  WLUNA-USDT
# 1542017  8.810327e+08  WLUNA-USDT
# 1542018  1.033588e+09  WLUNA-USDT
# 1542019  4.144895e+09  WLUNA-USDT
# 1542020  1.736733e+07  WLUNA-USDT
#
# [1542021 rows x 7 columns]

# %%
df['id'] = df['id'].str.replace('-', '')

# %%
df
# Out:
#                         time       low      high      open     close  \
# 0        2022-01-01 00:00:00  0.416200  0.420400  0.416600  0.419200
# 1        2022-01-01 01:00:00  0.419200  0.425000  0.419900  0.421100
# 2        2022-01-01 02:00:00  0.418600  0.422900  0.421100  0.418600
# 3        2022-01-01 03:00:00  0.418500  0.420400  0.418900  0.418600
# 4        2022-01-01 04:00:00  0.417300  0.419700  0.419400  0.418300
# ...                      ...       ...       ...       ...       ...
# 1542016  2022-05-27 12:00:00  0.000128  0.000136  0.000132  0.000131
# 1542017  2022-05-27 13:00:00  0.000122  0.000133  0.000131  0.000127
# 1542018  2022-05-27 14:00:00  0.000118  0.000130  0.000127  0.000128
# 1542019  2022-05-27 15:00:00  0.000114  0.000129  0.000129  0.000121
# 1542020  2022-05-27 16:00:00  0.000123  0.000128  0.000124  0.000126
#
#                volume         id
# 0        2.633730e+04    POWRUSD
# 1        5.698080e+04    POWRUSD
# 2        2.797330e+04    POWRUSD
# 3        2.638640e+04    POWRUSD
# 4        1.690010e+04    POWRUSD
# ...               ...        ...
# 1542016  7.154788e+08  WLUNAUSDT
# 1542017  8.810327e+08  WLUNAUSDT
# 1542018  1.033588e+09  WLUNAUSDT
# 1542019  4.144895e+09  WLUNAUSDT
# 1542020  1.736733e+07  WLUNAUSDT
#
# [1542021 rows x 7 columns]

# %%
df2 = pd.read_csv(r"C:\Users\ASUS Zephyrus G15\crypto-prediction\data\binance_data.csv")

# %%
df2
# Out:
#             datetime      open      high       low     close        volume  \
# 0       1.641013e+12  0.079385  0.079415  0.079000  0.079154  2.009493e+03
# 1       1.641017e+12  0.079148  0.079175  0.078940  0.079017  9.794588e+02
# 2       1.641020e+12  0.079016  0.079074  0.078714  0.078725  2.589111e+03
# 3       1.641024e+12  0.078724  0.079056  0.078680  0.078973  1.095375e+03
# 4       1.641028e+12  0.078976  0.079085  0.078869  0.078877  1.089094e+03
# ...              ...       ...       ...       ...       ...           ...
# 785014  1.654042e+12  0.021220  0.021731  0.020900  0.021590  2.530830e+07
# 785015  1.654045e+12  0.021590  0.022457  0.021125  0.021215  3.380712e+07
# 785016  1.654049e+12  0.021215  0.021387  0.020700  0.020956  2.812921e+07
# 785017  1.654052e+12  0.020955  0.021100  0.020700  0.020839  1.621105e+07
# 785018  1.654056e+12  0.020837  0.020908  0.019200  0.019405  5.959462e+07
#
#           symbol
# 0         ETHBTC
# 1         ETHBTC
# 2         ETHBTC
# 3         ETHBTC
# 4         ETHBTC
# ...          ...
# 785014  USTCBUSD
# 785015  USTCBUSD
# 785016  USTCBUSD
# 785017  USTCBUSD
# 785018  USTCBUSD
#
# [785019 rows x 7 columns]

# %%
df2['datetime'] = pd.to_datetime(df2['datetime'], unit='ms')
df2['datetime'] = df2['datetime'].dt.tz_localize('GMT').dt.tz_convert('US/Eastern')

# %%
df2
# Out:
#                         datetime      open      high       low     close  \
# 0      2022-01-01 00:00:00-05:00  0.079385  0.079415  0.079000  0.079154
# 1      2022-01-01 01:00:00-05:00  0.079148  0.079175  0.078940  0.079017
# 2      2022-01-01 02:00:00-05:00  0.079016  0.079074  0.078714  0.078725
# 3      2022-01-01 03:00:00-05:00  0.078724  0.079056  0.078680  0.078973
# 4      2022-01-01 04:00:00-05:00  0.078976  0.079085  0.078869  0.078877
# ...                          ...       ...       ...       ...       ...
# 785014 2022-05-31 20:00:00-04:00  0.021220  0.021731  0.020900  0.021590
# 785015 2022-05-31 21:00:00-04:00  0.021590  0.022457  0.021125  0.021215
# 785016 2022-05-31 22:00:00-04:00  0.021215  0.021387  0.020700  0.020956
# 785017 2022-05-31 23:00:00-04:00  0.020955  0.021100  0.020700  0.020839
# 785018 2022-06-01 00:00:00-04:00  0.020837  0.020908  0.019200  0.019405
#
#               volume    symbol
# 0       2.009493e+03    ETHBTC
# 1       9.794588e+02    ETHBTC
# 2       2.589111e+03    ETHBTC
# 3       1.095375e+03    ETHBTC
# 4       1.089094e+03    ETHBTC
# ...              ...       ...
# 785014  2.530830e+07  USTCBUSD
# 785015  3.380712e+07  USTCBUSD
# 785016  2.812921e+07  USTCBUSD
# 785017  1.621105e+07  USTCBUSD
# 785018  5.959462e+07  USTCBUSD
#
# [785019 rows x 7 columns]

# %%
# change datetime to string format
df2['datetime'] = df2['datetime'].dt.strftime('%Y-%m-%d %H:%M:%S')

# %%
df2
# Out:
#                    datetime      open      high       low     close  \
# 0       2022-01-01 00:00:00  0.079385  0.079415  0.079000  0.079154
# 1       2022-01-01 01:00:00  0.079148  0.079175  0.078940  0.079017
# 2       2022-01-01 02:00:00  0.079016  0.079074  0.078714  0.078725
# 3       2022-01-01 03:00:00  0.078724  0.079056  0.078680  0.078973
# 4       2022-01-01 04:00:00  0.078976  0.079085  0.078869  0.078877
# ...                     ...       ...       ...       ...       ...
# 785014  2022-05-31 20:00:00  0.021220  0.021731  0.020900  0.021590
# 785015  2022-05-31 21:00:00  0.021590  0.022457  0.021125  0.021215
# 785016  2022-05-31 22:00:00  0.021215  0.021387  0.020700  0.020956
# 785017  2022-05-31 23:00:00  0.020955  0.021100  0.020700  0.020839
# 785018  2022-06-01 00:00:00  0.020837  0.020908  0.019200  0.019405
#
#               volume    symbol
# 0       2.009493e+03    ETHBTC
# 1       9.794588e+02    ETHBTC
# 2       2.589111e+03    ETHBTC
# 3       1.095375e+03    ETHBTC
# 4       1.089094e+03    ETHBTC
# ...              ...       ...
# 785014  2.530830e+07  USTCBUSD
# 785015  3.380712e+07  USTCBUSD
# 785016  2.812921e+07  USTCBUSD
# 785017  1.621105e+07  USTCBUSD
# 785018  5.959462e+07  USTCBUSD
#
# [785019 rows x 7 columns]

# %%
df.columns = ['datetime', 'low', 'high', 'open', 'close', 'volume', 'symbol'] # changeing the column names

# %%
df = df[['datetime', 'open', 'high', 'low', 'close', 'volume', 'symbol']] # reordering the columns

# %%
combined_df = pd.concat([df, df2]) # combining the two dataframes

# %%
# removing duplicates from the combined dataframe and sorting it by datetime and symbol
# for duplicate keeping coinbase data is more reasonable choice since we are gonna use S&P500 and we are in US 
# there were 76567 duplicate rows 
combined_df = combined_df.drop_duplicates(subset=['datetime', 'symbol'], keep='first')

# %%
combined_df
# Out:
#                    datetime      open      high       low     close  \
# 0       2022-01-01 00:00:00  0.416200  0.420400  0.416600  0.419200
# 1       2022-01-01 01:00:00  0.419200  0.425000  0.419900  0.421100
# 2       2022-01-01 02:00:00  0.418600  0.422900  0.421100  0.418600
# 3       2022-01-01 03:00:00  0.418500  0.420400  0.418900  0.418600
# 4       2022-01-01 04:00:00  0.417300  0.419700  0.419400  0.418300
# ...                     ...       ...       ...       ...       ...
# 785014  2022-05-31 20:00:00  0.021220  0.021731  0.020900  0.021590
# 785015  2022-05-31 21:00:00  0.021590  0.022457  0.021125  0.021215
# 785016  2022-05-31 22:00:00  0.021215  0.021387  0.020700  0.020956
# 785017  2022-05-31 23:00:00  0.020955  0.021100  0.020700  0.020839
# 785018  2022-06-01 00:00:00  0.020837  0.020908  0.019200  0.019405
#
#             volume    symbol
# 0          26337.3   POWRUSD
# 1          56980.8   POWRUSD
# 2          27973.3   POWRUSD
# 3          26386.4   POWRUSD
# 4          16900.1   POWRUSD
# ...            ...       ...
# 785014  25308305.0  USTCBUSD
# 785015  33807118.0  USTCBUSD
# 785016  28129214.0  USTCBUSD
# 785017  16211054.0  USTCBUSD
# 785018  59594620.0  USTCBUSD
#
# [2250473 rows x 7 columns]

# %%
combined_df.to_csv(r"C:\Users\ASUS Zephyrus G15\crypto-prediction\data\combined_crypto.csv") # saving the dataframe to a csv file

# %%
combined_df = pd.read_csv(r"C:\Users\ASUS Zephyrus G15\DATA1030-Fall2021\crypto-prediction\data\combined_crypto.csv")

# %%
combined_df = combined_df.drop('Unnamed: 0', 1)
# Out:
# C:\Users\ASUS Zephyrus G15\AppData\Local\Temp\ipykernel_25760\2413763179.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   combined_df = combined_df.drop('Unnamed: 0', 1)

# %%
combined_df
# Out:
#                     datetime      open      high       low     close  \
# 0        2022-01-01 00:00:00  0.416200  0.420400  0.416600  0.419200
# 1        2022-01-01 01:00:00  0.419200  0.425000  0.419900  0.421100
# 2        2022-01-01 02:00:00  0.418600  0.422900  0.421100  0.418600
# 3        2022-01-01 03:00:00  0.418500  0.420400  0.418900  0.418600
# 4        2022-01-01 04:00:00  0.417300  0.419700  0.419400  0.418300
# ...                      ...       ...       ...       ...       ...
# 2250468  2022-05-31 20:00:00  0.021220  0.021731  0.020900  0.021590
# 2250469  2022-05-31 21:00:00  0.021590  0.022457  0.021125  0.021215
# 2250470  2022-05-31 22:00:00  0.021215  0.021387  0.020700  0.020956
# 2250471  2022-05-31 23:00:00  0.020955  0.021100  0.020700  0.020839
# 2250472  2022-06-01 00:00:00  0.020837  0.020908  0.019200  0.019405
#
#              volume    symbol
# 0           26337.3   POWRUSD
# 1           56980.8   POWRUSD
# 2           27973.3   POWRUSD
# 3           26386.4   POWRUSD
# 4           16900.1   POWRUSD
# ...             ...       ...
# 2250468  25308305.0  USTCBUSD
# 2250469  33807118.0  USTCBUSD
# 2250470  28129214.0  USTCBUSD
# 2250471  16211054.0  USTCBUSD
# 2250472  59594620.0  USTCBUSD
#
# [2250473 rows x 7 columns]

# %%
# contains symbol USD
combined_df_usd = combined_df[combined_df['symbol'].str.contains("USD")]

# %%
combined_df_usd
# Out:
#                     datetime      open      high       low     close  \
# 0        2022-01-01 00:00:00  0.416200  0.420400  0.416600  0.419200
# 1        2022-01-01 01:00:00  0.419200  0.425000  0.419900  0.421100
# 2        2022-01-01 02:00:00  0.418600  0.422900  0.421100  0.418600
# 3        2022-01-01 03:00:00  0.418500  0.420400  0.418900  0.418600
# 4        2022-01-01 04:00:00  0.417300  0.419700  0.419400  0.418300
# ...                      ...       ...       ...       ...       ...
# 2250468  2022-05-31 20:00:00  0.021220  0.021731  0.020900  0.021590
# 2250469  2022-05-31 21:00:00  0.021590  0.022457  0.021125  0.021215
# 2250470  2022-05-31 22:00:00  0.021215  0.021387  0.020700  0.020956
# 2250471  2022-05-31 23:00:00  0.020955  0.021100  0.020700  0.020839
# 2250472  2022-06-01 00:00:00  0.020837  0.020908  0.019200  0.019405
#
#              volume    symbol
# 0           26337.3   POWRUSD
# 1           56980.8   POWRUSD
# 2           27973.3   POWRUSD
# 3           26386.4   POWRUSD
# 4           16900.1   POWRUSD
# ...             ...       ...
# 2250468  25308305.0  USTCBUSD
# 2250469  33807118.0  USTCBUSD
# 2250470  28129214.0  USTCBUSD
# 2250471  16211054.0  USTCBUSD
# 2250472  59594620.0  USTCBUSD
#
# [1193170 rows x 7 columns]

# %%
combined_df_usd.to_csv(r"C:\Users\ASUS Zephyrus G15\crypto-prediction\data\combined_crypto_usd.csv") # saving the dataframe to a csv file

# %%
combined_df_btc = combined_df[combined_df['symbol'].str.contains("BUSD")]

# %%
combined_df_btc
# Out:
#          Unnamed: 0             datetime      open      high       low  \
# 912237       915308  2022-01-01 00:00:00  0.000033  0.000034  0.000034
# 912238       915309  2022-01-01 01:00:00  0.000034  0.000034  0.000034
# 912239       915310  2022-01-01 02:00:00  0.000034  0.000034  0.000034
# 912240       915311  2022-01-01 03:00:00  0.000034  0.000034  0.000034
# 912241       915312  2022-01-01 04:00:00  0.000033  0.000034  0.000034
# ...             ...                  ...       ...       ...       ...
# 2250468      785014  2022-05-31 20:00:00  0.021220  0.021731  0.020900
# 2250469      785015  2022-05-31 21:00:00  0.021590  0.022457  0.021125
# 2250470      785016  2022-05-31 22:00:00  0.021215  0.021387  0.020700
# 2250471      785017  2022-05-31 23:00:00  0.020955  0.021100  0.020700
# 2250472      785018  2022-06-01 00:00:00  0.020837  0.020908  0.019200
#
#             close        volume    symbol
# 912237   0.000034  8.835773e+09  SHIBUSDT
# 912238   0.000034  9.442488e+09  SHIBUSDT
# 912239   0.000034  6.510605e+09  SHIBUSDT
# 912240   0.000034  4.232022e+09  SHIBUSDT
# 912241   0.000034  9.855479e+09  SHIBUSDT
# ...           ...           ...       ...
# 2250468  0.021590  2.530830e+07  USTCBUSD
# 2250469  0.021215  3.380712e+07  USTCBUSD
# 2250470  0.020956  2.812921e+07  USTCBUSD
# 2250471  0.020839  1.621105e+07  USTCBUSD
# 2250472  0.019405  5.959462e+07  USTCBUSD
#
# [170561 rows x 8 columns]
