# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import time 
import sys 
from hmmlearn import hmm
import pickle
import os
import glob

# %% [markdown]
# ## Coding MAPE and R^2 Functions

# %%
# Function to calculate Mean Absolute Percentage Error 

def mape(predictions, truth): 
    #calculate the absolute value of the MAPE 
    abs_val = np.absolute(predictions - truth)
    div_op = np.divide(abs_val, truth)
    mape_val = np.divide(np.sum(div_op, 0), truth.shape[0])
    return mape_val

# %% [markdown]
# ## Data Read in Through Separate csv's

# %%
import os
import glob

path = '/Users/cho/Desktop/crypto-prediction/individual_series/data'
extension = 'csv'
os.chdir(path)
tickers = glob.glob('*.{}'.format(extension))
print(tickers[:3])
# Out:
# ['LTCBUSD.csv', 'EGLDBUSD.csv', 'GALAUSD.csv']

# %% [markdown]
# ## Testing

# %% [markdown]
# ## HMM Tuning

# %%
names = []
predicted = []
r = []
mape_vals = []
series_skipped = []

#for t in tickers: 

for t in tickers:
    try:

        table = np.genfromtxt(t, delimiter=',')
        table = table[1:,1:]
        #print(table)
        #table = table[:,:-1]
        #print(table)
        #table = np.reshape(table)
        table = np.flipud(table)


        #establish vectors for calculation 
        predicted_value = np.empty([0,table.shape[1]])

        #likelihood needed for HMM model 
        likelihood = np.empty([0,1])

        #Model metrics for evaluation 
        bic = np.empty([0,1])
        aic = np.empty([0,1])



        #metrics for evaluation
        for i in range(2,15):

            param_vals = i + (i**2)
            dirichlet_params = np.random.randint(1,50,i)

            #initialize model 
            mod = hmm.GaussianHMM(covariance_type = 'full', n_components = i, n_iter = 10**3, tol = 1e-4)
            mod.fit(table[100:,:])

            #sanity check to recount number of epochs
            if mod.monitor_.iter == 10**4:
                sys.exit(1)
                print("Epoch Increased by 1")

            #append values to metrics array of vectors 
            likelihood = np.vstack((likelihood, mod.score(table)))
            bic = np.vstack((bic, -2*mod.score(table) + param_vals * np.log(table.shape[0])))
            aic = np.vstack((aic, -2*mod.score(table) + 2* param_vals))

        #calculate the number of states in the model 
        #opt_states_aic = np.argmin(aic) + 2
        opt_states_bic = np.argmin(bic) + 2
        print(opt_states_bic)

        #print(table)

        pred_val_array = []

        for i in reversed(range(100)): 
            train = table[i+2:,:]
            #print(train.shape)
            test = table[i,:]
            #print(test.shape)
            tot_vals = train.shape[0]

            #model tuning 
            if i == 99: 
                mod = hmm.GaussianHMM(n_components = opt_states_bic, covariance_type = 'full', tol = 1e-4, n_iter = 10**3,  init_params = 'stmc')
            #refactor for prior distribution and retune
            else: 
                mod = hmm.GaussianHMM(n_components = opt_states_bic, covariance_type = 'full', tol = 1e-4, n_iter = 10**3,  init_params = '')
                mod.transmat_ = transmat_retune_prior
                mod.startprob_ = startprob_retune_prior
                mod.means_ = means_retune_prior
                mod.covars_ = covars_retune_prior


            mod.fit(np.flipud(train))

            #values tuned parameters updated
            transmat_retune_prior = mod.transmat_
            startprob_retune_prior = mod.startprob_
            means_retune_prior = mod.means_
            covars_retune_prior = mod.covars_

            #sanity check to recount number of epochs
            if mod.monitor_.iter == 10**4: 
                sys.exit(1)
                print("Epoch Increased by 1")

            #compute likehoods using model params such that we can generate predictions
            counter = 1 
            former_lkhd = []
            current_lkhd = mod.score(np.flipud(train[0:48,:]))

            while counter < tot_vals/48: 
                scoring = mod.score(np.flipud(train[counter:counter + 48,:]))
                former_lkhd = np.append(former_lkhd,scoring)
                counter += 1

            abs_diffs = np.absolute(former_lkhd - current_lkhd)
            min_i = np.argmin(abs_diffs)
            pred_change = train[min_i,:] - train[2 + min_i,:]
            predicted_value = np.vstack((predicted_value, table[i + 2,:] + pred_change))
            #print(predicted_value)
        predicted.append(predicted_value)


        #calculate mape
        mean_average = mape(predicted_value, np.flipud(table[range(100), :]))
        mape_vals.append(mean_average)
        
        names.append(t)
        
    except:
        print("failed csv:", t)
        series_skipped.append(t)
        continue
# Out:
# 13
# 14
# 12
# 14
# 10
# 14
# 14
# 13
# 12
# failed csv: HARDBUSD.csv
# 14
# 14
# 13
# 14
# 14
# failed csv: CHZUSD.csv
# 14
# 13
# failed csv: BTCSTBUSD.csv
# 14
# 14
# 14
# 13
# 13
# failed csv: TUSDBUSD.csv
# 11
# 12
# 13
# failed csv: GBPBUSD.csv
# 12
# 14
# 14
# 14
# 12
# failed csv: PSGBUSD.csv
# 13
# 8
# 14
# 10
# 14
# 14
# 14
# failed csv: GHSTBUSD.csv
# 14
# 14
# 14
# 13
# 10
# 14
# 13
# failed csv: BTGBUSD.csv
# 14
# 13
# 14
# 13
# 13
# failed csv: FIOBUSD.csv
# 14
# 13
# 14
# 14
# failed csv: NMRBUSD.csv
# 14
# failed csv: SPELLUSD.csv
# 11
# 14
# 14
# failed csv: STMXBUSD.csv
# 14
# 13
# 14
# 13
# 14
# 7
# 14
# 14
# 11
# failed csv: AUCTIONBUSD.csv
# 13
# 14
# 13
# 6
# failed csv: USDPBUSD.csv
# 14
# 8
# failed csv: HOTBUSD.csv
# 14
# 14
# 14
# 12
# 14
# 13
# 14
# failed csv: DOCKBUSD.csv
# 14
# failed csv: DATABUSD.csv
# 14
# 10
# failed csv: JUVBUSD.csv
# 14
# failed csv: DEXEBUSD.csv
# 14
# 14
# 13
# 14
# 14
# 13
# 14
# 10
# failed csv: XVGBUSD.csv
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 13
# 13
# 11
# 12
# failed csv: BARBUSD.csv
# 14
# 14
# 14
# 10
# failed csv: QUICKBUSD.csv
# 14
# failed csv: LSKBUSD.csv
# 14
# 14
# 13
# 12
# 14
# 13
# 14
# 13
# failed csv: DEGOBUSD.csv
# 14
# 14
# 9
# failed csv: TRBBUSD.csv
# 14
# 14
# 14
# 13
# 14
# 12
# 14
# 11
# failed csv: PHABUSD.csv
# 14
# 14
# 10
# failed csv: BNTBUSD.csv
# 13
# 13
# 14
# 12
# 14
# 14
# 9
# 13
# 13
# 14
# 14
# 13
# 14
# failed csv: DENTBUSD.csv
# 14
# 14
# 13
# 13
# 13
# 11
# 14
# 14
# 11
# 14
# 14
# 13
# 14
# 14
# 14
# 14
# 13
# 14
# 14
# failed csv: ORNBUSD.csv
# 14
# 14
# 14
# 13
# 12
# 13
# 14
# 13
# 13
# 14
# 14
# failed csv: UTKBUSD.csv
# 14
# failed csv: STPTBUSD.csv
# 13
# 13
# failed csv: EURBUSD.csv
# 13
# failed csv: DNTBUSD.csv
# 13
# 14
# 13
# failed csv: ALCXBUSD.csv
# 13
# 14
# 8
# failed csv: WINBUSD.csv
# 14
# 14
# 14
# 13
# failed csv: RADBUSD.csv
# 12
# 6
# failed csv: USDCBUSD.csv
# 14
# 14
# 14
# 13
# 10
# 14
# failed csv: WINGBUSD.csv
# 6
# failed csv: PLABUSD.csv
# 14
# 14
# 14
# 12
# failed csv: DGBBUSD.csv
# 14
# 14
# 14
# failed csv: SCBUSD.csv
# 12
# 14
# 14
# 13
# 14
# 14
# failed csv: POWRBUSD.csv
# 14
# 11
# 14
# 9
# 13
# 12
# failed csv: USDTUSDC.csv
# 14
# 13
# 12
# 13
# 14
# failed csv: CKBBUSD.csv
# 14
# 14
# 14
# 14
# 14
# 14
# 13
# 14
# 13
# failed csv: ATMBUSD.csv
# 9
# 12
# 13
# 14
# 12
# failed csv: USDTUSD.csv
# 13
# 14
# 9
# 14
# 11
# 13
# 12
# 14
# 14
# 14
# 14
# 13
# 14
# 13
# 14
# 14
# 14
# 13
# 14
# 14
# 13
# 14
# failed csv: SUNBUSD.csv
# 14
# 14
# 14
# 14
# 14
# 13
# 13
# 14
# 12
# 12
# 14
# 13
# 14
# 9
# failed csv: LPTBUSD.csv
# failed csv: XECBUSD.csv
# 13
# 14
# 14
# failed csv: ADATUSD.csv
# 13
# 14
# 13
# 14
# 14
# 13
# failed csv: XRPTUSD.csv
# failed csv: SPELLBUSD.csv
# 14
# 11
# 14
# 11
# 14
# 14
# 14
# 2
# 13
# 10
# failed csv: MLNBUSD.csv
# failed csv: REEFBUSD.csv
# 14
# 12
# 14
# 14
# 14
# 12
# 14
# 11
# failed csv: CLVUSD.csv
# 13
# 14
# 14
# 14
# 14
# 13
# 14
# 9
# 13
# 12
# failed csv: NULSBUSD.csv
# 2
# failed csv: TROYBUSD.csv
# 14
# 13
# 14
# 13
# 14
# 12
# 14
# 14
# 13
# 14
# 14
# 14
# 14
# 12
# failed csv: OXTBUSD.csv
# 14
# 8
# 14
# 12
# 14
# 13
# 14
# 14
# failed csv: AUTOBUSD.csv
# 12
# 14
# 12
# 14
# 14
# failed csv: FETBUSD.csv
# 13
# 13
# 14
# failed csv: GYENUSD.csv
# 14
# 14
# 13
# 14
# 14
# 11
# 14
# 11
# 14
# 12
# failed csv: LTOBUSD.csv
# 14
# 12
# 14
# 10
# 14
# 14
# 14
# 11
# 14
# 14
# 13
# 13
# 12
# 13
# 14
# 14
# 14
# 13
# 14
# 11
# 9
# failed csv: IQBUSD.csv
# 12
# 14
# 12
# 14
# 13
# 14

# %%
names
# Out:
# ['LTCBUSD.csv',
#  'EGLDBUSD.csv',
#  'GALAUSD.csv',
#  'MIRBUSD.csv',
#  'CELRBUSD.csv',
#  'PYRBUSD.csv',
#  'POWRUSD.csv',
#  'XVSBUSD.csv',
#  'BNBBUSD.csv',
#  'YFIBUSD.csv',
#  'ACMBUSD.csv',
#  'EOSUSD.csv',
#  'BAKEBUSD.csv',
#  'QTUMBUSD.csv',
#  'FISBUSD.csv',
#  'ARBUSD.csv',
#  'MLNUSD.csv',
#  'COVALUSD.csv',
#  'VETBUSD.csv',
#  'ERNBUSD.csv',
#  'IOTXBUSD.csv',
#  'ELFBUSD.csv',
#  'DOTUSDT.csv',
#  'LAZIOBUSD.csv',
#  'MDTUSD.csv',
#  'LINABUSD.csv',
#  'SNXBUSD.csv',
#  'ANKRBUSD.csv',
#  'HIVEBUSD.csv',
#  'RENBUSD.csv',
#  'BICOBUSD.csv',
#  'ATOMBUSD.csv',
#  'DARBUSD.csv',
#  'POLYBUSD.csv',
#  'MATICUSD.csv',
#  'DOGEUSD.csv',
#  'RARIUSD.csv',
#  'MANAUSD.csv',
#  'COMPBUSD.csv',
#  'INJBUSD.csv',
#  'THETABUSD.csv',
#  'ZECUSD.csv',
#  'DIABUSD.csv',
#  'ALGOUSD.csv',
#  'AMPUSD.csv',
#  'CTSIBUSD.csv',
#  'FTTBUSD.csv',
#  'CELOBUSD.csv',
#  'BADGERBUSD.csv',
#  'RENUSD.csv',
#  'BALUSD.csv',
#  'NKNUSD.csv',
#  'OOKIBUSD.csv',
#  'BADGERUSD.csv',
#  'DYDXBUSD.csv',
#  'SOLBUSD.csv',
#  'LPTUSD.csv',
#  'CROUSD.csv',
#  'ZRXBUSD.csv',
#  'JSTBUSD.csv',
#  'HNTBUSD.csv',
#  'BCHUSD.csv',
#  'ETHUSD.csv',
#  'KRLUSD.csv',
#  'BATUSD.csv',
#  'AERGOBUSD.csv',
#  'PLAUSD.csv',
#  'AVAXUSDT.csv',
#  'HIGHBUSD.csv',
#  'BCHBUSD.csv',
#  'ICPUSD.csv',
#  'FETUSD.csv',
#  'ENSUSD.csv',
#  'FARMUSD.csv',
#  'MDXBUSD.csv',
#  'CGLDUSD.csv',
#  'KP3RBUSD.csv',
#  'NUUSD.csv',
#  'API3USD.csv',
#  'BNBTUSD.csv',
#  'GRTBUSD.csv',
#  'WRXBUSD.csv',
#  'ZECBUSD.csv',
#  'GTCBUSD.csv',
#  'BONDBUSD.csv',
#  'AUCTIONUSD.csv',
#  'MANABUSD.csv',
#  'CHESSBUSD.csv',
#  'PERPBUSD.csv',
#  'ONTBUSD.csv',
#  'SCRTBUSD.csv',
#  'BALBUSD.csv',
#  'POLYUSD.csv',
#  'PEOPLEBUSD.csv',
#  'SOLUSDT.csv',
#  'CTXCBUSD.csv',
#  'LTCUSD.csv',
#  'USDTEUR.csv',
#  'ENJBUSD.csv',
#  'FILBUSD.csv',
#  'LINKBUSD.csv',
#  'POLSBUSD.csv',
#  'GRTUSD.csv',
#  'SOLUSD.csv',
#  'REQBUSD.csv',
#  'IOTXUSD.csv',
#  'SUPERBUSD.csv',
#  'ATOMUSD.csv',
#  'BETABUSD.csv',
#  'SUSHIUSD.csv',
#  'CFXBUSD.csv',
#  'DASHBUSD.csv',
#  'FORBUSD.csv',
#  'GTCUSD.csv',
#  'OMGBUSD.csv',
#  'AVAXBUSD.csv',
#  'OGNBUSD.csv',
#  'RVNBUSD.csv',
#  'NEARBUSD.csv',
#  'ADXBUSD.csv',
#  'AAVEBUSD.csv',
#  'LRCBUSD.csv',
#  'SUSHIBUSD.csv',
#  'MBOXBUSD.csv',
#  'FORTHBUSD.csv',
#  'MASKUSD.csv',
#  'BIFIBUSD.csv',
#  'JASMYBUSD.csv',
#  'DESOUSD.csv',
#  'MOVRBUSD.csv',
#  'RUNEBUSD.csv',
#  'SNXUSD.csv',
#  'PROMBUSD.csv',
#  'KEEPUSD.csv',
#  'FIDABUSD.csv',
#  'ALPHABUSD.csv',
#  'JOEBUSD.csv',
#  'FOXUSD.csv',
#  'ALCXUSD.csv',
#  'UFTBUSD.csv',
#  'ATABUSD.csv',
#  'ARPAUSD.csv',
#  'BANDUSD.csv',
#  'QNTBUSD.csv',
#  'DOGEBUSD.csv',
#  'ROSEBUSD.csv',
#  'DASHUSD.csv',
#  'QIBUSD.csv',
#  'CITYBUSD.csv',
#  'DOTBUSD.csv',
#  'VOXELBUSD.csv',
#  'OMGUSD.csv',
#  'IOSTBUSD.csv',
#  'FRONTBUSD.csv',
#  'CVPBUSD.csv',
#  'FORTHUSD.csv',
#  'TRUUSD.csv',
#  'KNCBUSD.csv',
#  'KSMBUSD.csv',
#  'DODOBUSD.csv',
#  'PONDBUSD.csv',
#  'SLPBUSD.csv',
#  'STORJUSD.csv',
#  'TRIBEBUSD.csv',
#  'TRACUSD.csv',
#  'XRPBUSD.csv',
#  'OMBUSD.csv',
#  'ADABUSD.csv',
#  'ONEBUSD.csv',
#  'LCXUSD.csv',
#  'MASKBUSD.csv',
#  'WAXPBUSD.csv',
#  'TVKBUSD.csv',
#  'FXUSD.csv',
#  'YGGBUSD.csv',
#  'AUDBUSD.csv',
#  'UNFIBUSD.csv',
#  'COSBUSD.csv',
#  'IDEXUSD.csv',
#  'XLMUSD.csv',
#  'BTCUSD.csv',
#  'AGLDBUSD.csv',
#  'ASMUSD.csv',
#  'BATBUSD.csv',
#  'SFPBUSD.csv',
#  'RLYUSD.csv',
#  'MIRUSD.csv',
#  'KLAYBUSD.csv',
#  'KNCUSD.csv',
#  'RAMPBUSD.csv',
#  'AXSBUSD.csv',
#  'ACHUSD.csv',
#  'NEOBUSD.csv',
#  'MATICBUSD.csv',
#  'GALABUSD.csv',
#  'BELBUSD.csv',
#  'ANTBUSD.csv',
#  'FLUXBUSD.csv',
#  'VIDTBUSD.csv',
#  'RSRBUSD.csv',
#  'XLMBUSD.csv',
#  'SKLUSD.csv',
#  'COCOSBUSD.csv',
#  'SRMBUSD.csv',
#  'RAYBUSD.csv',
#  'YFIUSD.csv',
#  'CTSIUSD.csv',
#  'ENJUSD.csv',
#  'CAKEBUSD.csv',
#  'WAVESBUSD.csv',
#  'ENSBUSD.csv',
#  'CVXBUSD.csv',
#  'EOSBUSD.csv',
#  'XTZBUSD.csv',
#  'LINKUSD.csv',
#  'RLCUSD.csv',
#  'VGXUSD.csv',
#  'COMPUSD.csv',
#  'COTIBUSD.csv',
#  'RAREBUSD.csv',
#  'SXPBUSD.csv',
#  'ETHUSDT.csv',
#  'ETHUSDC.csv',
#  'BTCUSDC.csv',
#  'MCBUSD.csv',
#  'GODSUSD.csv',
#  'BTCUSDT.csv',
#  'OXTUSD.csv',
#  'CRVUSD.csv',
#  'ETCBUSD.csv',
#  'BONDUSD.csv',
#  'WBTCUSD.csv',
#  'MKRBUSD.csv',
#  'C98BUSD.csv',
#  'AXSUSD.csv',
#  'SANDBUSD.csv',
#  'MINABUSD.csv',
#  'RADUSD.csv',
#  'ILVBUSD.csv',
#  'BNXBUSD.csv',
#  'ANKRUSD.csv',
#  'AGLDUSD.csv',
#  'XYOUSD.csv',
#  'QUICKUSD.csv',
#  'RBNUSD.csv',
#  'CTKBUSD.csv',
#  'SHIBUSD.csv',
#  'ICPUSDT.csv',
#  '1INCHUSD.csv',
#  'KAVABUSD.csv',
#  'BLZUSD.csv',
#  'STORJBUSD.csv',
#  'ETHBUSD.csv',
#  'OCEANBUSD.csv',
#  'AVABUSD.csv',
#  'CLVBUSD.csv',
#  'DOTUSD.csv',
#  'TLMBUSD.csv',
#  'ORNUSD.csv',
#  '1INCHBUSD.csv',
#  'BICOUSD.csv',
#  'IDEXBUSD.csv',
#  'TRXTUSD.csv',
#  'TWTBUSD.csv',
#  'SHIBBUSD.csv',
#  'RNDRBUSD.csv',
#  'OGNUSD.csv',
#  'FLOWBUSD.csv',
#  'ALGOBUSD.csv',
#  'UMAUSD.csv',
#  'TKOBUSD.csv',
#  'IMXUSD.csv',
#  'BURGERBUSD.csv',
#  'ICPBUSD.csv',
#  'TOMOBUSD.csv',
#  'FILUSD.csv',
#  'COTIUSD.csv',
#  'HBARBUSD.csv',
#  'AUDIOBUSD.csv',
#  'MDTBUSD.csv',
#  'QNTUSD.csv',
#  'ZRXUSD.csv',
#  'PERPUSD.csv',
#  'XMRBUSD.csv',
#  'BTCBUSD.csv',
#  'CHRBUSD.csv',
#  'TORNBUSD.csv',
#  'AMPBUSD.csv',
#  'BTCTUSD.csv',
#  'CREAMBUSD.csv',
#  'ZENBUSD.csv',
#  'LRCUSD.csv',
#  'IOTABUSD.csv',
#  'BANDBUSD.csv',
#  'LITBUSD.csv',
#  'CVCUSD.csv',
#  'STRAXBUSD.csv',
#  'USDCEUR.csv',
#  'FARMBUSD.csv',
#  'ARPABUSD.csv',
#  'REQUSD.csv',
#  'ALICEBUSD.csv',
#  'ETCUSD.csv',
#  'NMRUSD.csv',
#  'DFBUSD.csv',
#  'MKRUSD.csv',
#  'UNIUSD.csv',
#  'XTZUSD.csv',
#  'TRXBUSD.csv',
#  'ADAUSD.csv',
#  'SUKUUSD.csv',
#  'ZILBUSD.csv',
#  'ICXBUSD.csv',
#  'SKLBUSD.csv',
#  'GALAUSDT.csv',
#  'FXSBUSD.csv',
#  'UNIBUSD.csv',
#  'FTMBUSD.csv',
#  'ALPACABUSD.csv',
#  'CHZBUSD.csv',
#  'STXBUSD.csv',
#  'JASMYUSD.csv',
#  'AAVEUSD.csv',
#  'SYSBUSD.csv',
#  'AVAXUSD.csv',
#  'ETHTUSD.csv',
#  'MTLBUSD.csv',
#  'CRVBUSD.csv']

# %%
#pwd

# %%
from sklearn.metrics import r2_score 

ex_object = [names, predicted, r, mape_vals]
name_array = np.array(ex_object[0])
print(name_array)
index_array = []
r2_array = []
opening_mape = []

for i in name_array: 
    #load indices for the coin pairs that we need 
    idx = np.where(name_array == i)[0][0]
    index_array.append(idx)
    print(i)
    
    #get data frame that we need for coin pairs 
    df = pd.read_csv('{}'.format(i))

    
    #predicted values 
    values = pd.DataFrame(ex_object[1][idx], columns = ['Open', 'High', 'Low', 'Close'])
    predicted_values = values.iloc[:,0]
    
    #actual values
    actual_values = df.iloc[-100:]
    actual_values = actual_values.iloc[:,1]
    
    r2 = r2_score(actual_values,predicted_values)
    r2_array.append(r2)
    
    mape_score = ex_object[3][idx][1]
    opening_mape.append(mape_score)
    
    #r2 scores
    print("name:{}, \n MAPE Open:{}, \n r2 score:{}".format(ex_object[0][idx], ex_object[3][idx][1], r2))
# Out:
# ['LTCBUSD.csv' 'EGLDBUSD.csv' 'GALAUSD.csv' 'MIRBUSD.csv' 'CELRBUSD.csv'
#  'PYRBUSD.csv' 'POWRUSD.csv' 'XVSBUSD.csv' 'BNBBUSD.csv' 'YFIBUSD.csv'
#  'ACMBUSD.csv' 'EOSUSD.csv' 'BAKEBUSD.csv' 'QTUMBUSD.csv' 'FISBUSD.csv'
#  'ARBUSD.csv' 'MLNUSD.csv' 'COVALUSD.csv' 'VETBUSD.csv' 'ERNBUSD.csv'
#  'IOTXBUSD.csv' 'ELFBUSD.csv' 'DOTUSDT.csv' 'LAZIOBUSD.csv' 'MDTUSD.csv'
#  'LINABUSD.csv' 'SNXBUSD.csv' 'ANKRBUSD.csv' 'HIVEBUSD.csv' 'RENBUSD.csv'
#  'BICOBUSD.csv' 'ATOMBUSD.csv' 'DARBUSD.csv' 'POLYBUSD.csv' 'MATICUSD.csv'
#  'DOGEUSD.csv' 'RARIUSD.csv' 'MANAUSD.csv' 'COMPBUSD.csv' 'INJBUSD.csv'
#  'THETABUSD.csv' 'ZECUSD.csv' 'DIABUSD.csv' 'ALGOUSD.csv' 'AMPUSD.csv'
#  'CTSIBUSD.csv' 'FTTBUSD.csv' 'CELOBUSD.csv' 'BADGERBUSD.csv' 'RENUSD.csv'
#  'BALUSD.csv' 'NKNUSD.csv' 'OOKIBUSD.csv' 'BADGERUSD.csv' 'DYDXBUSD.csv'
#  'SOLBUSD.csv' 'LPTUSD.csv' 'CROUSD.csv' 'ZRXBUSD.csv' 'JSTBUSD.csv'
#  'HNTBUSD.csv' 'BCHUSD.csv' 'ETHUSD.csv' 'KRLUSD.csv' 'BATUSD.csv'
#  'FARMBUSD.csv' 'ARPABUSD.csv' 'REQUSD.csv' 'ALICEBUSD.csv' 'ETCUSD.csv'
#  'NMRUSD.csv' 'DFBUSD.csv' 'MKRUSD.csv' 'UNIUSD.csv' 'XTZUSD.csv'
#  'TRXBUSD.csv' 'ADAUSD.csv' 'SUKUUSD.csv' 'ZILBUSD.csv' 'ICXBUSD.csv'
#  'SKLBUSD.csv' 'GALAUSDT.csv' 'FXSBUSD.csv' 'UNIBUSD.csv' 'FTMBUSD.csv'
#  'ALPACABUSD.csv' 'CHZBUSD.csv' 'STXBUSD.csv' 'JASMYUSD.csv' 'AAVEUSD.csv'
#  'SYSBUSD.csv' 'AVAXUSD.csv' 'ETHTUSD.csv' 'MTLBUSD.csv' 'CRVBUSD.csv']
# LTCBUSD.csv
# name:LTCBUSD.csv,
#  MAPE Open:0.010351680709980328,
#  r2 score:0.8695091562355124
# EGLDBUSD.csv
# name:EGLDBUSD.csv,
#  MAPE Open:0.02030262534465369,
#  r2 score:0.9187449022936057
# GALAUSD.csv
# name:GALAUSD.csv,
#  MAPE Open:0.020517776289596643,
#  r2 score:0.8387678809530081
# MIRBUSD.csv
# name:MIRBUSD.csv,
#  MAPE Open:0.04149174094461384,
#  r2 score:-0.3574578268299613
# CELRBUSD.csv
# name:CELRBUSD.csv,
#  MAPE Open:0.01891525284275506,
#  r2 score:0.8764984909450177
# PYRBUSD.csv
# name:PYRBUSD.csv,
#  MAPE Open:0.023294131933421353,
#  r2 score:0.8648932047467134
# POWRUSD.csv
# name:POWRUSD.csv,
#  MAPE Open:0.014082420679159956,
#  r2 score:0.8503741682176247
# XVSBUSD.csv
# name:XVSBUSD.csv,
#  MAPE Open:0.020801782381031877,
#  r2 score:0.8235189475956933
# BNBBUSD.csv
# name:BNBBUSD.csv,
#  MAPE Open:0.010619026062822525,
#  r2 score:0.8207526818337496
# YFIBUSD.csv
# name:YFIBUSD.csv,
#  MAPE Open:0.016912638451067833,
#  r2 score:0.7196985107534173
# ACMBUSD.csv
# name:ACMBUSD.csv,
#  MAPE Open:0.025752887964807056,
#  r2 score:-2.1994251406716887
# EOSUSD.csv
# name:EOSUSD.csv,
#  MAPE Open:0.011161063899864397,
#  r2 score:0.8848876577408435
# BAKEBUSD.csv
# name:BAKEBUSD.csv,
#  MAPE Open:0.023744311284755123,
#  r2 score:0.9008837396173297
# QTUMBUSD.csv
# name:QTUMBUSD.csv,
#  MAPE Open:0.014834852036609255,
#  r2 score:0.8434186524727086
# FISBUSD.csv
# name:FISBUSD.csv,
#  MAPE Open:0.05359053739030259,
#  r2 score:-0.3093984883346377
# ARBUSD.csv
# name:ARBUSD.csv,
#  MAPE Open:0.01978551959011534,
#  r2 score:0.8447266403613867
# MLNUSD.csv
# name:MLNUSD.csv,
#  MAPE Open:0.029325061371682688,
#  r2 score:0.48580879684577316
# COVALUSD.csv
# name:COVALUSD.csv,
#  MAPE Open:0.01815083664363578,
#  r2 score:0.48391361069789984
# VETBUSD.csv
# name:VETBUSD.csv,
#  MAPE Open:0.01221432565426013,
#  r2 score:0.8509927021590145
# ERNBUSD.csv
# name:ERNBUSD.csv,
#  MAPE Open:0.013700770644635343,
#  r2 score:0.6570647664227895
# IOTXBUSD.csv
# name:IOTXBUSD.csv,
#  MAPE Open:0.018206155900497522,
#  r2 score:0.8113506836873944
# ELFBUSD.csv
# name:ELFBUSD.csv,
#  MAPE Open:0.030552218580388923,
#  r2 score:-0.6674449245835983
# DOTUSDT.csv
# name:DOTUSDT.csv,
#  MAPE Open:0.02007882197075594,
#  r2 score:0.7111459877762847
# LAZIOBUSD.csv
# name:LAZIOBUSD.csv,
#  MAPE Open:0.018168159751512994,
#  r2 score:-0.8917283944916334
# MDTUSD.csv
# name:MDTUSD.csv,
#  MAPE Open:0.01912596706991705,
#  r2 score:0.874811081980519
# LINABUSD.csv
# name:LINABUSD.csv,
#  MAPE Open:0.03540448527819692,
#  r2 score:0.7034588736842774
# SNXBUSD.csv
# name:SNXBUSD.csv,
#  MAPE Open:0.02748707361843463,
#  r2 score:0.879533903730678
# ANKRBUSD.csv
# name:ANKRBUSD.csv,
#  MAPE Open:0.016805436883941295,
#  r2 score:0.599812615742741
# HIVEBUSD.csv
# name:HIVEBUSD.csv,
#  MAPE Open:0.0316890185282263,
#  r2 score:0.7588149492549257
# RENBUSD.csv
# name:RENBUSD.csv,
#  MAPE Open:0.020393246426226575,
#  r2 score:0.8358663834850559
# BICOBUSD.csv
# name:BICOBUSD.csv,
#  MAPE Open:0.027248195664563553,
#  r2 score:0.8501786750912321
# ATOMBUSD.csv
# name:ATOMBUSD.csv,
#  MAPE Open:0.01726257224885717,
#  r2 score:0.752122394514177
# DARBUSD.csv
# name:DARBUSD.csv,
#  MAPE Open:0.01951725527014883,
#  r2 score:0.7870953353700634
# POLYBUSD.csv
# name:POLYBUSD.csv,
#  MAPE Open:0.018622367597412558,
#  r2 score:0.7726109426983183
# MATICUSD.csv
# name:MATICUSD.csv,
#  MAPE Open:0.01449747674548955,
#  r2 score:0.8441054625477721
# DOGEUSD.csv
# name:DOGEUSD.csv,
#  MAPE Open:0.01658808547249822,
#  r2 score:0.4762769436143258
# RARIUSD.csv
# name:RARIUSD.csv,
#  MAPE Open:0.01799970662907764,
#  r2 score:0.6736621869665116
# MANAUSD.csv
# name:MANAUSD.csv,
#  MAPE Open:0.016603648852847652,
#  r2 score:0.8688154741303868
# COMPBUSD.csv
# name:COMPBUSD.csv,
#  MAPE Open:0.020344004641122338,
#  r2 score:0.7766563604838732
# INJBUSD.csv
# name:INJBUSD.csv,
#  MAPE Open:0.025296877410313022,
#  r2 score:0.6596737622130211
# THETABUSD.csv
# name:THETABUSD.csv,
#  MAPE Open:0.01772653098593185,
#  r2 score:0.9187126093690599
# ZECUSD.csv
# name:ZECUSD.csv,
#  MAPE Open:0.017473624969535785,
#  r2 score:0.7314814154442221
# DIABUSD.csv
# name:DIABUSD.csv,
#  MAPE Open:0.036059897508675914,
#  r2 score:0.28011621075163917
# ALGOUSD.csv
# name:ALGOUSD.csv,
#  MAPE Open:0.015721203699978134,
#  r2 score:0.8700448761128775
# AMPUSD.csv
# name:AMPUSD.csv,
#  MAPE Open:0.010216073495779927,
#  r2 score:0.7203725327759944
# CTSIBUSD.csv
# name:CTSIBUSD.csv,
#  MAPE Open:0.020274405011465286,
#  r2 score:0.8009322979600202
# FTTBUSD.csv
# name:FTTBUSD.csv,
#  MAPE Open:0.00820273369293841,
#  r2 score:0.8663986064162035
# CELOBUSD.csv
# name:CELOBUSD.csv,
#  MAPE Open:0.0161840972167222,
#  r2 score:0.7654383853934585
# BADGERBUSD.csv
# name:BADGERBUSD.csv,
#  MAPE Open:0.014050194957170603,
#  r2 score:0.7602846084132314
# RENUSD.csv
# name:RENUSD.csv,
#  MAPE Open:0.019744702059833776,
#  r2 score:0.8595749615611092
# BALUSD.csv
# name:BALUSD.csv,
#  MAPE Open:0.01982620149705317,
#  r2 score:0.7004542138182672
# NKNUSD.csv
# name:NKNUSD.csv,
#  MAPE Open:0.0267411821643377,
#  r2 score:0.8131542697512633
# OOKIBUSD.csv
# name:OOKIBUSD.csv,
#  MAPE Open:0.02708348526737027,
#  r2 score:0.6130820451523067
# BADGERUSD.csv
# name:BADGERUSD.csv,
#  MAPE Open:0.014422298457156433,
#  r2 score:0.726708155352078
# DYDXBUSD.csv
# name:DYDXBUSD.csv,
#  MAPE Open:0.020842397399922025,
#  r2 score:0.863110735683612
# SOLBUSD.csv
# name:SOLBUSD.csv,
#  MAPE Open:0.018578864971489743,
#  r2 score:0.671593550058998
# LPTUSD.csv
# name:LPTUSD.csv,
#  MAPE Open:0.016789816697802253,
#  r2 score:0.6963448961137131
# CROUSD.csv
# name:CROUSD.csv,
#  MAPE Open:0.012883158896296612,
#  r2 score:0.882538014977169
# ZRXBUSD.csv
# name:ZRXBUSD.csv,
#  MAPE Open:0.01898910977471223,
#  r2 score:0.775170688582684
# JSTBUSD.csv
# name:JSTBUSD.csv,
#  MAPE Open:0.011786609752183035,
#  r2 score:0.7335576421810909
# HNTBUSD.csv
# name:HNTBUSD.csv,
#  MAPE Open:0.02475281669925974,
#  r2 score:0.9076644981617976
# BCHUSD.csv
# name:BCHUSD.csv,
#  MAPE Open:0.012079173446287603,
#  r2 score:0.8995541865902987
# ETHUSD.csv
# name:ETHUSD.csv,
#  MAPE Open:0.010218227856537376,
#  r2 score:0.9049553787707861
# KRLUSD.csv
# name:KRLUSD.csv,
#  MAPE Open:0.014506112473080902,
#  r2 score:0.615424985591799
# BATUSD.csv
# name:BATUSD.csv,
#  MAPE Open:0.016391850853614873,
#  r2 score:0.676687668766877
# AERGOBUSD.csv
# name:AERGOBUSD.csv,
#  MAPE Open:0.01770944659350624,
#  r2 score:0.8843350995291116
# PLAUSD.csv
# name:PLAUSD.csv,
#  MAPE Open:0.013653292728717825,
#  r2 score:0.8409915126847323
# AVAXUSDT.csv
# name:AVAXUSDT.csv,
#  MAPE Open:0.027305083267698874,
#  r2 score:0.7537211279180169
# HIGHBUSD.csv
# name:HIGHBUSD.csv,
#  MAPE Open:0.021435214234147296,
#  r2 score:0.8285859499614815
# BCHBUSD.csv
# name:BCHBUSD.csv,
#  MAPE Open:0.013379397674530532,
#  r2 score:0.8895094823464454
# ICPUSD.csv
# name:ICPUSD.csv,
#  MAPE Open:0.020960887406903998,
#  r2 score:0.7866677369348907
# FETUSD.csv
# name:FETUSD.csv,
#  MAPE Open:0.02806754977060117,
#  r2 score:0.8476464727982742
# ENSUSD.csv
# name:ENSUSD.csv,
#  MAPE Open:0.021839929158267837,
#  r2 score:0.8907852322689611
# FARMUSD.csv
# name:FARMUSD.csv,
#  MAPE Open:0.026184082825691988,
#  r2 score:0.7497568586460606
# MDXBUSD.csv
# name:MDXBUSD.csv,
#  MAPE Open:0.01040856932151359,
#  r2 score:0.8340168382964228
# CGLDUSD.csv
# name:CGLDUSD.csv,
#  MAPE Open:0.018796765443056057,
#  r2 score:0.7705595193390908
# KP3RBUSD.csv
# name:KP3RBUSD.csv,
#  MAPE Open:0.02852041454409529,
#  r2 score:0.6355409158260539
# NUUSD.csv
# name:NUUSD.csv,
#  MAPE Open:0.012699059162587907,
#  r2 score:0.7903555549871487
# API3USD.csv
# name:API3USD.csv,
#  MAPE Open:0.022610431193998366,
#  r2 score:0.7385651523464613
# BNBTUSD.csv
# name:BNBTUSD.csv,
#  MAPE Open:0.00957511283808019,
#  r2 score:0.757858313265698
# GRTBUSD.csv
# name:GRTBUSD.csv,
#  MAPE Open:0.019237842702921636,
#  r2 score:0.7785221080535218
# WRXBUSD.csv
# name:WRXBUSD.csv,
#  MAPE Open:0.015405423870248165,
#  r2 score:0.8907542247586753
# ZECBUSD.csv
# name:ZECBUSD.csv,
#  MAPE Open:0.013846216888122183,
#  r2 score:0.777514378983367
# GTCBUSD.csv
# name:GTCBUSD.csv,
#  MAPE Open:0.03414901264300657,
#  r2 score:0.7363412402837863
# BONDBUSD.csv
# name:BONDBUSD.csv,
#  MAPE Open:0.01809484416072953,
#  r2 score:0.7071137114658247
# AUCTIONUSD.csv
# name:AUCTIONUSD.csv,
#  MAPE Open:0.03650434586517141,
#  r2 score:0.5442494276950052
# MANABUSD.csv
# name:MANABUSD.csv,
#  MAPE Open:0.016543776878464714,
#  r2 score:0.8382412363394253
# CHESSBUSD.csv
# name:CHESSBUSD.csv,
#  MAPE Open:0.036635051728215684,
#  r2 score:0.7838172037440391
# PERPBUSD.csv
# name:PERPBUSD.csv,
#  MAPE Open:0.03492765918980985,
#  r2 score:0.5211939313359639
# ONTBUSD.csv
# name:ONTBUSD.csv,
#  MAPE Open:0.013139058719599483,
#  r2 score:0.7858374888598232
# SCRTBUSD.csv
# name:SCRTBUSD.csv,
#  MAPE Open:0.016037884755634696,
#  r2 score:0.6400841314482011
# BALBUSD.csv
# name:BALBUSD.csv,
#  MAPE Open:0.019778750694326688,
#  r2 score:0.7142453175045911
# POLYUSD.csv
# name:POLYUSD.csv,
#  MAPE Open:0.013409629643614857,
#  r2 score:0.7972286214108002
# PEOPLEBUSD.csv
# name:PEOPLEBUSD.csv,
#  MAPE Open:0.03696221506511607,
#  r2 score:0.1298334035755413
# SOLUSDT.csv
# name:SOLUSDT.csv,
#  MAPE Open:0.018787050628952348,
#  r2 score:0.7439337341017762
# CTXCBUSD.csv
# name:CTXCBUSD.csv,
#  MAPE Open:0.04053482020527337,
#  r2 score:-1.7709293161133641
# LTCUSD.csv
# name:LTCUSD.csv,
#  MAPE Open:0.0102019983312173,
#  r2 score:0.8761692233701808
# USDTEUR.csv
# name:USDTEUR.csv,
#  MAPE Open:0.0007754094602696792,
#  r2 score:0.5582184042184984
# ENJBUSD.csv
# name:ENJBUSD.csv,
#  MAPE Open:0.017645332649906698,
#  r2 score:0.905027841247091
# FILBUSD.csv
# name:FILBUSD.csv,
#  MAPE Open:0.015430541261050524,
#  r2 score:0.7893470312724893
# LINKBUSD.csv
# name:LINKBUSD.csv,
#  MAPE Open:0.01717154225058279,
#  r2 score:0.9122937165926396
# POLSBUSD.csv
# name:POLSBUSD.csv,
#  MAPE Open:0.012559770034385978,
#  r2 score:0.8221610665761375
# GRTUSD.csv
# name:GRTUSD.csv,
#  MAPE Open:0.018893056055720635,
#  r2 score:0.7813377721470621
# SOLUSD.csv
# name:SOLUSD.csv,
#  MAPE Open:0.01825870248466339,
#  r2 score:0.7380968892797721
# REQBUSD.csv
# name:REQBUSD.csv,
#  MAPE Open:0.01980318401408797,
#  r2 score:0.29890202225565665
# IOTXUSD.csv
# name:IOTXUSD.csv,
#  MAPE Open:0.026447174602577304,
#  r2 score:0.8694929900745874
# SUPERBUSD.csv
# name:SUPERBUSD.csv,
#  MAPE Open:0.03731652224972847,
#  r2 score:0.7506806882433308
# ATOMUSD.csv
# name:ATOMUSD.csv,
#  MAPE Open:0.017536139038587625,
#  r2 score:0.7991924628126056
# BETABUSD.csv
# name:BETABUSD.csv,
#  MAPE Open:0.04428937398587526,
#  r2 score:0.14644132153594802
# SUSHIUSD.csv
# name:SUSHIUSD.csv,
#  MAPE Open:0.019884943840526133,
#  r2 score:0.8594855070304648
# CFXBUSD.csv
# name:CFXBUSD.csv,
#  MAPE Open:0.020684879535566324,
#  r2 score:-0.007168870998658594
# DASHBUSD.csv
# name:DASHBUSD.csv,
#  MAPE Open:0.01287340735075671,
#  r2 score:0.9038758395604672
# FORBUSD.csv
# name:FORBUSD.csv,
#  MAPE Open:0.02213893173614667,
#  r2 score:0.8368582842424553
# GTCUSD.csv
# name:GTCUSD.csv,
#  MAPE Open:0.0325574515826842,
#  r2 score:0.7510231569169814
# OMGBUSD.csv
# name:OMGBUSD.csv,
#  MAPE Open:0.01639725547482228,
#  r2 score:0.8641866443043924
# AVAXBUSD.csv
# name:AVAXBUSD.csv,
#  MAPE Open:0.02461137011336359,
#  r2 score:0.742077891798443
# OGNBUSD.csv
# name:OGNBUSD.csv,
#  MAPE Open:0.051569083288552954,
#  r2 score:0.846214742392484
# RVNBUSD.csv
# name:RVNBUSD.csv,
#  MAPE Open:0.015777936133969505,
#  r2 score:0.8046437841342625
# NEARBUSD.csv
# name:NEARBUSD.csv,
#  MAPE Open:0.01896076750851221,
#  r2 score:0.9043851181892326
# ADXBUSD.csv
# name:ADXBUSD.csv,
#  MAPE Open:0.01183162542894735,
#  r2 score:0.8704355216866173
# AAVEBUSD.csv
# name:AAVEBUSD.csv,
#  MAPE Open:0.019371572218464795,
#  r2 score:0.9238142552955898
# LRCBUSD.csv
# name:LRCBUSD.csv,
#  MAPE Open:0.01962700149572695,
#  r2 score:0.8411466207463277
# SUSHIBUSD.csv
# name:SUSHIBUSD.csv,
#  MAPE Open:0.021280946021121072,
#  r2 score:0.8852071728514868
# MBOXBUSD.csv
# name:MBOXBUSD.csv,
#  MAPE Open:0.019738514786120296,
#  r2 score:0.8282350201343347
# FORTHBUSD.csv
# name:FORTHBUSD.csv,
#  MAPE Open:0.05683651522335961,
#  r2 score:-0.06287320177045186
# MASKUSD.csv
# name:MASKUSD.csv,
#  MAPE Open:0.02247434441278067,
#  r2 score:0.7976718093909645
# BIFIBUSD.csv
# name:BIFIBUSD.csv,
#  MAPE Open:0.02102209412662024,
#  r2 score:0.6220345597013904
# JASMYBUSD.csv
# name:JASMYBUSD.csv,
#  MAPE Open:0.021761284125915905,
#  r2 score:0.7510685006765918
# DESOUSD.csv
# name:DESOUSD.csv,
#  MAPE Open:0.017138587402332362,
#  r2 score:0.7408396211093036
# MOVRBUSD.csv
# name:MOVRBUSD.csv,
#  MAPE Open:0.013507044410128049,
#  r2 score:0.7453385830150625
# RUNEBUSD.csv
# name:RUNEBUSD.csv,
#  MAPE Open:0.025081204131593825,
#  r2 score:0.9045825356319928
# SNXUSD.csv
# name:SNXUSD.csv,
#  MAPE Open:0.02752617296565539,
#  r2 score:0.8472736706253575
# PROMBUSD.csv
# name:PROMBUSD.csv,
#  MAPE Open:0.018906497311474296,
#  r2 score:0.5087920385469908
# KEEPUSD.csv
# name:KEEPUSD.csv,
#  MAPE Open:0.022466438143814268,
#  r2 score:0.8140051951024205
# FIDABUSD.csv
# name:FIDABUSD.csv,
#  MAPE Open:0.0361334652982638,
#  r2 score:0.45884435348603136
# ALPHABUSD.csv
# name:ALPHABUSD.csv,
#  MAPE Open:0.029566561512627446,
#  r2 score:0.7792145671789433
# JOEBUSD.csv
# name:JOEBUSD.csv,
#  MAPE Open:0.03684108977151851,
#  r2 score:0.6688834464278497
# FOXUSD.csv
# name:FOXUSD.csv,
#  MAPE Open:0.041580374111761895,
#  r2 score:-0.295124101710009
# ALCXUSD.csv
# name:ALCXUSD.csv,
#  MAPE Open:0.025734113655392292,
#  r2 score:0.18601129831822005
# UFTBUSD.csv
# name:UFTBUSD.csv,
#  MAPE Open:0.04662987497755742,
#  r2 score:-0.6036981688592593
# ATABUSD.csv
# name:ATABUSD.csv,
#  MAPE Open:0.02517912813788855,
#  r2 score:0.8331176367876925
# ARPAUSD.csv
# name:ARPAUSD.csv,
#  MAPE Open:0.03783615684918087,
#  r2 score:0.7774700180655856
# BANDUSD.csv
# name:BANDUSD.csv,
#  MAPE Open:0.02103151409613256,
#  r2 score:0.8825121754425322
# QNTBUSD.csv
# name:QNTBUSD.csv,
#  MAPE Open:0.015634886256532202,
#  r2 score:0.8171500966150143
# DOGEBUSD.csv
# name:DOGEBUSD.csv,
#  MAPE Open:0.016013399152978516,
#  r2 score:0.5460321973977313
# ROSEBUSD.csv
# name:ROSEBUSD.csv,
#  MAPE Open:0.020461897562151946,
#  r2 score:0.8694055727404499
# DASHUSD.csv
# name:DASHUSD.csv,
#  MAPE Open:0.012359673055460405,
#  r2 score:0.9061548165662914
# QIBUSD.csv
# name:QIBUSD.csv,
#  MAPE Open:0.02456157390368791,
#  r2 score:0.747502996404315
# CITYBUSD.csv
# name:CITYBUSD.csv,
#  MAPE Open:0.017852138100476204,
#  r2 score:-1.1317664804985554
# DOTBUSD.csv
# name:DOTBUSD.csv,
#  MAPE Open:0.01735072027902099,
#  r2 score:0.739596819204456
# VOXELBUSD.csv
# name:VOXELBUSD.csv,
#  MAPE Open:0.027087865484685104,
#  r2 score:0.6875699874182924
# OMGUSD.csv
# name:OMGUSD.csv,
#  MAPE Open:0.015627762453837128,
#  r2 score:0.8684071573305874
# IOSTBUSD.csv
# name:IOSTBUSD.csv,
#  MAPE Open:0.01175749621198949,
#  r2 score:0.9005613461761641
# FRONTBUSD.csv
# name:FRONTBUSD.csv,
#  MAPE Open:0.023846832459140318,
#  r2 score:0.7349646094759532
# CVPBUSD.csv
# name:CVPBUSD.csv,
#  MAPE Open:0.022422134283342207,
#  r2 score:0.7949520617295636
# FORTHUSD.csv
# name:FORTHUSD.csv,
#  MAPE Open:0.04825202565158194,
#  r2 score:0.362348680521724
# TRUUSD.csv
# name:TRUUSD.csv,
#  MAPE Open:0.040537356596548293,
#  r2 score:0.5867356336641072
# KNCBUSD.csv
# name:KNCBUSD.csv,
#  MAPE Open:0.027272437320190537,
#  r2 score:0.8355830688814574
# KSMBUSD.csv
# name:KSMBUSD.csv,
#  MAPE Open:0.01887330053761066,
#  r2 score:0.8372043543309039
# DODOBUSD.csv
# name:DODOBUSD.csv,
#  MAPE Open:0.051305595127384016,
#  r2 score:0.6514788199860371
# PONDBUSD.csv
# name:PONDBUSD.csv,
#  MAPE Open:0.02488072997878949,
#  r2 score:0.8429174524000905
# SLPBUSD.csv
# name:SLPBUSD.csv,
#  MAPE Open:0.01929421213201216,
#  r2 score:0.8131186847646766
# STORJUSD.csv
# name:STORJUSD.csv,
#  MAPE Open:0.016282047991704095,
#  r2 score:0.6194639211857633
# TRIBEBUSD.csv
# name:TRIBEBUSD.csv,
#  MAPE Open:0.01089811808321554,
#  r2 score:-0.664753497413104
# TRACUSD.csv
# name:TRACUSD.csv,
#  MAPE Open:0.027874068903327758,
#  r2 score:0.8047203977491689
# XRPBUSD.csv
# name:XRPBUSD.csv,
#  MAPE Open:0.009860492989990555,
#  r2 score:0.9066308038965177
# OMBUSD.csv
# name:OMBUSD.csv,
#  MAPE Open:0.016793238944626667,
#  r2 score:0.76922948288452
# ADABUSD.csv
# name:ADABUSD.csv,
#  MAPE Open:0.020126166043177338,
#  r2 score:0.9433104331869405
# ONEBUSD.csv
# name:ONEBUSD.csv,
#  MAPE Open:0.017522273102527394,
#  r2 score:0.7504186222838861
# LCXUSD.csv
# name:LCXUSD.csv,
#  MAPE Open:0.02256731573645253,
#  r2 score:0.5223382397140903
# MASKBUSD.csv
# name:MASKBUSD.csv,
#  MAPE Open:0.024651137147219674,
#  r2 score:0.8326127761722294
# WAXPBUSD.csv
# name:WAXPBUSD.csv,
#  MAPE Open:0.017441382109302312,
#  r2 score:0.8792520577796736
# TVKBUSD.csv
# name:TVKBUSD.csv,
#  MAPE Open:0.020508821440393444,
#  r2 score:0.7472036530146342
# FXUSD.csv
# name:FXUSD.csv,
#  MAPE Open:0.0363409716113638,
#  r2 score:0.5243019810618295
# YGGBUSD.csv
# name:YGGBUSD.csv,
#  MAPE Open:0.03920278077595882,
#  r2 score:0.6430207366140513
# AUDBUSD.csv
# name:AUDBUSD.csv,
#  MAPE Open:0.0011795501653910046,
#  r2 score:0.6302771146186916
# UNFIBUSD.csv
# name:UNFIBUSD.csv,
#  MAPE Open:0.053324185368022636,
#  r2 score:0.8971138037380907
# COSBUSD.csv
# name:COSBUSD.csv,
#  MAPE Open:0.01885386517281096,
#  r2 score:0.8278802093821696
# IDEXUSD.csv
# name:IDEXUSD.csv,
#  MAPE Open:0.02833204548817294,
#  r2 score:0.00858137780727286
# XLMUSD.csv
# name:XLMUSD.csv,
#  MAPE Open:0.010710133725973426,
#  r2 score:0.9417163328818295
# BTCUSD.csv
# name:BTCUSD.csv,
#  MAPE Open:0.00836566360476561,
#  r2 score:0.8958791449452558
# AGLDBUSD.csv
# name:AGLDBUSD.csv,
#  MAPE Open:0.01939701776456041,
#  r2 score:0.7903591640209984
# ASMUSD.csv
# name:ASMUSD.csv,
#  MAPE Open:0.03625501665688358,
#  r2 score:0.5277030478497151
# BATBUSD.csv
# name:BATBUSD.csv,
#  MAPE Open:0.014884052013716776,
#  r2 score:0.7989462628225453
# SFPBUSD.csv
# name:SFPBUSD.csv,
#  MAPE Open:0.022197644211873202,
#  r2 score:0.8385297747408381
# RLYUSD.csv
# name:RLYUSD.csv,
#  MAPE Open:0.014050534807610123,
#  r2 score:0.8174794644117399
# MIRUSD.csv
# name:MIRUSD.csv,
#  MAPE Open:0.04241236441778252,
#  r2 score:-0.2545690942334047
# KLAYBUSD.csv
# name:KLAYBUSD.csv,
#  MAPE Open:0.011039705799597208,
#  r2 score:0.7273338920431072
# KNCUSD.csv
# name:KNCUSD.csv,
#  MAPE Open:0.028093892564710538,
#  r2 score:0.8029580077282865
# RAMPBUSD.csv
# name:RAMPBUSD.csv,
#  MAPE Open:0.024921401397859002,
#  r2 score:0.664047366199465
# AXSBUSD.csv
# name:AXSBUSD.csv,
#  MAPE Open:0.0286965161660417,
#  r2 score:0.881143620827301
# ACHUSD.csv
# name:ACHUSD.csv,
#  MAPE Open:0.021373124450529773,
#  r2 score:0.07111698766223895
# NEOBUSD.csv
# name:NEOBUSD.csv,
#  MAPE Open:0.015439120773027335,
#  r2 score:0.8615522544872634
# MATICBUSD.csv
# name:MATICBUSD.csv,
#  MAPE Open:0.013866589963848801,
#  r2 score:0.8219558377661593
# GALABUSD.csv
# name:GALABUSD.csv,
#  MAPE Open:0.02152774984513032,
#  r2 score:0.8389861543129572
# BELBUSD.csv
# name:BELBUSD.csv,
#  MAPE Open:0.09677940714713303,
#  r2 score:0.82605041525811
# ANTBUSD.csv
# name:ANTBUSD.csv,
#  MAPE Open:0.029640693556351853,
#  r2 score:0.8504769517327443
# FLUXBUSD.csv
# name:FLUXBUSD.csv,
#  MAPE Open:0.016527298133370477,
#  r2 score:0.8040667910200632
# VIDTBUSD.csv
# name:VIDTBUSD.csv,
#  MAPE Open:0.020752543194113623,
#  r2 score:0.8577231203587514
# RSRBUSD.csv
# name:RSRBUSD.csv,
#  MAPE Open:0.03611072821903122,
#  r2 score:0.8941752019684952
# XLMBUSD.csv
# name:XLMBUSD.csv,
#  MAPE Open:0.011709281920596367,
#  r2 score:0.9384235416598239
# SKLUSD.csv
# name:SKLUSD.csv,
#  MAPE Open:0.0293413442776207,
#  r2 score:0.7594260703295391
# COCOSBUSD.csv
# name:COCOSBUSD.csv,
#  MAPE Open:0.021867441655733386,
#  r2 score:0.6903203752822269
# SRMBUSD.csv
# name:SRMBUSD.csv,
#  MAPE Open:0.016825312730005648,
#  r2 score:0.7482994427979452
# RAYBUSD.csv
# name:RAYBUSD.csv,
#  MAPE Open:0.020624227195525698,
#  r2 score:0.8013459892538971
# YFIUSD.csv
# name:YFIUSD.csv,
#  MAPE Open:0.01706829783592526,
#  r2 score:0.7106543388082462
# CTSIUSD.csv
# name:CTSIUSD.csv,
#  MAPE Open:0.016601161613244174,
#  r2 score:0.8288807778447768
# ENJUSD.csv
# name:ENJUSD.csv,
#  MAPE Open:0.017993886829267475,
#  r2 score:0.8783383378662444
# CAKEBUSD.csv
# name:CAKEBUSD.csv,
#  MAPE Open:0.011193325218932935,
#  r2 score:0.8252519265052003
# WAVESBUSD.csv
# name:WAVESBUSD.csv,
#  MAPE Open:0.05944268335949027,
#  r2 score:0.9117551883940168
# ENSBUSD.csv
# name:ENSBUSD.csv,
#  MAPE Open:0.025741751634790956,
#  r2 score:0.8743638661396593
# CVXBUSD.csv
# name:CVXBUSD.csv,
#  MAPE Open:0.020110199599384603,
#  r2 score:0.8012779055383619
# EOSBUSD.csv
# name:EOSBUSD.csv,
#  MAPE Open:0.009971067413925061,
#  r2 score:0.8795398821942905
# XTZBUSD.csv
# name:XTZBUSD.csv,
#  MAPE Open:0.01708368427391039,
#  r2 score:0.7894148497934151
# LINKUSD.csv
# name:LINKUSD.csv,
#  MAPE Open:0.017984760168073884,
#  r2 score:0.8878640833114645
# RLCUSD.csv
# name:RLCUSD.csv,
#  MAPE Open:0.02389703100621422,
#  r2 score:0.8714334500699751
# VGXUSD.csv
# name:VGXUSD.csv,
#  MAPE Open:0.02162375588054587,
#  r2 score:0.6893765292581588
# COMPUSD.csv
# name:COMPUSD.csv,
#  MAPE Open:0.01947895729200978,
#  r2 score:0.8191475261772749
# COTIBUSD.csv
# name:COTIBUSD.csv,
#  MAPE Open:0.016395068126137037,
#  r2 score:0.8555357975020044
# RAREBUSD.csv
# name:RAREBUSD.csv,
#  MAPE Open:0.03519700377485455,
#  r2 score:0.49108456296567404
# SXPBUSD.csv
# name:SXPBUSD.csv,
#  MAPE Open:0.01138791766117935,
#  r2 score:0.850534375744437
# ETHUSDT.csv
# name:ETHUSDT.csv,
#  MAPE Open:0.011657881553132259,
#  r2 score:0.8968000921780912
# ETHUSDC.csv
# name:ETHUSDC.csv,
#  MAPE Open:0.011008540538569544,
#  r2 score:0.8987831411677002
# BTCUSDC.csv
# name:BTCUSDC.csv,
#  MAPE Open:0.00848342222587672,
#  r2 score:0.8992705986146889
# MCBUSD.csv
# name:MCBUSD.csv,
#  MAPE Open:0.016273496495541953,
#  r2 score:0.7445124860823922
# GODSUSD.csv
# name:GODSUSD.csv,
#  MAPE Open:0.037249078942012875,
#  r2 score:0.5741183436488891
# BTCUSDT.csv
# name:BTCUSDT.csv,
#  MAPE Open:0.008154788746460521,
#  r2 score:0.8957780345171517
# OXTUSD.csv
# name:OXTUSD.csv,
#  MAPE Open:0.043837906888166536,
#  r2 score:-1.9216764948902463
# CRVUSD.csv
# name:CRVUSD.csv,
#  MAPE Open:0.018523955707252036,
#  r2 score:0.8146278718912566
# ETCBUSD.csv
# name:ETCBUSD.csv,
#  MAPE Open:0.012936746600433697,
#  r2 score:0.5364322733778557
# BONDUSD.csv
# name:BONDUSD.csv,
#  MAPE Open:0.022517981805439805,
#  r2 score:0.589125276091975
# WBTCUSD.csv
# name:WBTCUSD.csv,
#  MAPE Open:0.00881156425571203,
#  r2 score:0.922220756187212
# MKRBUSD.csv
# name:MKRBUSD.csv,
#  MAPE Open:0.01725179142479582,
#  r2 score:0.7859839916532319
# C98BUSD.csv
# name:C98BUSD.csv,
#  MAPE Open:0.025159870967361643,
#  r2 score:0.9058893759659244
# AXSUSD.csv
# name:AXSUSD.csv,
#  MAPE Open:0.027942865145068056,
#  r2 score:0.868184918258341
# SANDBUSD.csv
# name:SANDBUSD.csv,
#  MAPE Open:0.018373697086579707,
#  r2 score:0.7984471129075381
# MINABUSD.csv
# name:MINABUSD.csv,
#  MAPE Open:0.019585463174484445,
#  r2 score:0.8629742590118665
# RADUSD.csv
# name:RADUSD.csv,
#  MAPE Open:0.03779207685325952,
#  r2 score:0.07440715695086497
# ILVBUSD.csv
# name:ILVBUSD.csv,
#  MAPE Open:0.015594265216525134,
#  r2 score:0.9149269487592714
# BNXBUSD.csv
# name:BNXBUSD.csv,
#  MAPE Open:0.01614488105137539,
#  r2 score:0.7094102237718372
# ANKRUSD.csv
# name:ANKRUSD.csv,
#  MAPE Open:0.01571046107445704,
#  r2 score:0.7303768099410543
# AGLDUSD.csv
# name:AGLDUSD.csv,
#  MAPE Open:0.017891718639011674,
#  r2 score:0.7810859748284849
# XYOUSD.csv
# name:XYOUSD.csv,
#  MAPE Open:0.01567739975023278,
#  r2 score:0.7170355800293775
# QUICKUSD.csv
# name:QUICKUSD.csv,
#  MAPE Open:0.016567769181567448,
#  r2 score:0.8660320196460835
# RBNUSD.csv
# name:RBNUSD.csv,
#  MAPE Open:0.02596930575749361,
#  r2 score:-0.7210416043100869
# CTKBUSD.csv
# name:CTKBUSD.csv,
#  MAPE Open:0.018789695193358682,
#  r2 score:0.75514169326818
# SHIBUSD.csv
# name:SHIBUSD.csv,
#  MAPE Open:0.01937693733601735,
#  r2 score:0.7407284101926206
# ICPUSDT.csv
# name:ICPUSDT.csv,
#  MAPE Open:0.021489160096633136,
#  r2 score:0.830781512454146
# 1INCHUSD.csv
# name:1INCHUSD.csv,
#  MAPE Open:0.010622401715497555,
#  r2 score:0.826553389832281
# KAVABUSD.csv
# name:KAVABUSD.csv,
#  MAPE Open:0.028061832222441317,
#  r2 score:0.8184242602683446
# BLZUSD.csv
# name:BLZUSD.csv,
#  MAPE Open:0.023880370162691938,
#  r2 score:0.6162764703417611
# STORJBUSD.csv
# name:STORJBUSD.csv,
#  MAPE Open:0.018051801158441377,
#  r2 score:0.817686190838006
# ETHBUSD.csv
# name:ETHBUSD.csv,
#  MAPE Open:0.009779565174019272,
#  r2 score:0.9091249782463009
# OCEANBUSD.csv
# name:OCEANBUSD.csv,
#  MAPE Open:0.02307235973518405,
#  r2 score:0.8208302087837702
# AVABUSD.csv
# name:AVABUSD.csv,
#  MAPE Open:0.013237646491385556,
#  r2 score:0.9189395228583412
# CLVBUSD.csv
# name:CLVBUSD.csv,
#  MAPE Open:0.027162619904594724,
#  r2 score:0.7173478132575446
# DOTUSD.csv
# name:DOTUSD.csv,
#  MAPE Open:0.017267708868893946,
#  r2 score:0.7449885839429661
# TLMBUSD.csv
# name:TLMBUSD.csv,
#  MAPE Open:0.015615498244801476,
#  r2 score:0.8879710277549004
# ORNUSD.csv
# name:ORNUSD.csv,
#  MAPE Open:0.0309501011051539,
#  r2 score:-0.9085261570222487
# 1INCHBUSD.csv
# name:1INCHBUSD.csv,
#  MAPE Open:0.011153189864536804,
#  r2 score:0.8176069919929074
# BICOUSD.csv
# name:BICOUSD.csv,
#  MAPE Open:0.028950588328491685,
#  r2 score:0.7768244566810809
# IDEXBUSD.csv
# name:IDEXBUSD.csv,
#  MAPE Open:0.025881090664340287,
#  r2 score:-0.285874813171477
# TRXTUSD.csv
# name:TRXTUSD.csv,
#  MAPE Open:0.011059562853798905,
#  r2 score:-0.14004147636778663
# TWTBUSD.csv
# name:TWTBUSD.csv,
#  MAPE Open:0.0167393087689025,
#  r2 score:0.784129707479364
# SHIBBUSD.csv
# name:SHIBBUSD.csv,
#  MAPE Open:0.016879254473570426,
#  r2 score:0.7528099061418139
# RNDRBUSD.csv
# name:RNDRBUSD.csv,
#  MAPE Open:0.027054675101443406,
#  r2 score:0.8266702761109563
# OGNUSD.csv
# name:OGNUSD.csv,
#  MAPE Open:0.04379718952679978,
#  r2 score:0.8179668963069605
# FLOWBUSD.csv
# name:FLOWBUSD.csv,
#  MAPE Open:0.017216280380228544,
#  r2 score:0.8650749082648476
# ALGOBUSD.csv
# name:ALGOBUSD.csv,
#  MAPE Open:0.016200184398395674,
#  r2 score:0.8676909224742485
# UMAUSD.csv
# name:UMAUSD.csv,
#  MAPE Open:0.01868610751483432,
#  r2 score:0.5661488123883139
# TKOBUSD.csv
# name:TKOBUSD.csv,
#  MAPE Open:0.023369672345900653,
#  r2 score:0.7205971258730239
# IMXUSD.csv
# name:IMXUSD.csv,
#  MAPE Open:0.02471719652741511,
#  r2 score:0.8657941561297939
# BURGERBUSD.csv
# name:BURGERBUSD.csv,
#  MAPE Open:0.054380256320403574,
#  r2 score:-0.4117601531689905
# ICPBUSD.csv
# name:ICPBUSD.csv,
#  MAPE Open:0.022201172778614744,
#  r2 score:0.8133120282464217
# TOMOBUSD.csv
# name:TOMOBUSD.csv,
#  MAPE Open:0.028356049986881668,
#  r2 score:0.8901042495201127
# FILUSD.csv
# name:FILUSD.csv,
#  MAPE Open:0.01435274880177165,
#  r2 score:0.7759985622919331
# COTIUSD.csv
# name:COTIUSD.csv,
#  MAPE Open:0.01807842028589881,
#  r2 score:0.8371166557629253
# HBARBUSD.csv
# name:HBARBUSD.csv,
#  MAPE Open:0.015858415755985452,
#  r2 score:0.6784459011297703
# AUDIOBUSD.csv
# name:AUDIOBUSD.csv,
#  MAPE Open:0.024627756572663397,
#  r2 score:0.8143292441977887
# MDTBUSD.csv
# name:MDTBUSD.csv,
#  MAPE Open:0.02081110210839598,
#  r2 score:0.8743321703408191
# QNTUSD.csv
# name:QNTUSD.csv,
#  MAPE Open:0.01369433673633202,
#  r2 score:0.8209375027257967
# ZRXUSD.csv
# name:ZRXUSD.csv,
#  MAPE Open:0.017007634288923937,
#  r2 score:0.818701726975794
# PERPUSD.csv
# name:PERPUSD.csv,
#  MAPE Open:0.030986929924997905,
#  r2 score:0.5965099331918267
# XMRBUSD.csv
# name:XMRBUSD.csv,
#  MAPE Open:0.014776104322832209,
#  r2 score:0.9027622306514775
# BTCBUSD.csv
# name:BTCBUSD.csv,
#  MAPE Open:0.00796567732547693,
#  r2 score:0.9187155137018747
# CHRBUSD.csv
# name:CHRBUSD.csv,
#  MAPE Open:0.027289204859462398,
#  r2 score:0.8011277585146165
# TORNBUSD.csv
# name:TORNBUSD.csv,
#  MAPE Open:0.034954293092959665,
#  r2 score:0.7067311365290576
# AMPBUSD.csv
# name:AMPBUSD.csv,
#  MAPE Open:0.010984907058932505,
#  r2 score:0.7873711340206183
# BTCTUSD.csv
# name:BTCTUSD.csv,
#  MAPE Open:0.007017759933297656,
#  r2 score:0.927343903178048
# CREAMBUSD.csv
# name:CREAMBUSD.csv,
#  MAPE Open:0.026697166252332802,
#  r2 score:-0.03686581745704376
# ZENBUSD.csv
# name:ZENBUSD.csv,
#  MAPE Open:0.015741596545689764,
#  r2 score:0.8948791765550068
# LRCUSD.csv
# name:LRCUSD.csv,
#  MAPE Open:0.017199689626370984,
#  r2 score:0.8089888053859879
# IOTABUSD.csv
# name:IOTABUSD.csv,
#  MAPE Open:0.015435842950881382,
#  r2 score:0.7876898890329757
# BANDBUSD.csv
# name:BANDBUSD.csv,
#  MAPE Open:0.019125566830978557,
#  r2 score:0.8799447885542343
# LITBUSD.csv
# name:LITBUSD.csv,
#  MAPE Open:0.037690858743336865,
#  r2 score:0.8710726925903388
# CVCUSD.csv
# name:CVCUSD.csv,
#  MAPE Open:0.019288381737076657,
#  r2 score:0.5754376097583208
# STRAXBUSD.csv
# name:STRAXBUSD.csv,
#  MAPE Open:0.02070318939570824,
#  r2 score:0.6410440176940195
# USDCEUR.csv
# name:USDCEUR.csv,
#  MAPE Open:0.0006922179698890707,
#  r2 score:0.6695717592547746
# FARMBUSD.csv
# name:FARMBUSD.csv,
#  MAPE Open:0.02288788754343899,
#  r2 score:0.7912156658488203
# ARPABUSD.csv
# name:ARPABUSD.csv,
#  MAPE Open:0.035627320165382434,
#  r2 score:0.7691284071025275
# REQUSD.csv
# name:REQUSD.csv,
#  MAPE Open:0.02135803247986777,
#  r2 score:0.458466005265995
# ALICEBUSD.csv
# name:ALICEBUSD.csv,
#  MAPE Open:0.019950581218075348,
#  r2 score:0.8228292201279446
# ETCUSD.csv
# name:ETCUSD.csv,
#  MAPE Open:0.011915083064640827,
#  r2 score:0.6854029858645885
# NMRUSD.csv
# name:NMRUSD.csv,
#  MAPE Open:0.012875812331870549,
#  r2 score:0.8040383053109488
# DFBUSD.csv
# name:DFBUSD.csv,
#  MAPE Open:0.024160883504071723,
#  r2 score:0.8880434838025513
# MKRUSD.csv
# name:MKRUSD.csv,
#  MAPE Open:0.018748358121479108,
#  r2 score:0.793941533623099
# UNIUSD.csv
# name:UNIUSD.csv,
#  MAPE Open:0.018002265318442887,
#  r2 score:0.907896748257703
# XTZUSD.csv
# name:XTZUSD.csv,
#  MAPE Open:0.014990881148753434,
#  r2 score:0.818928329369825
# TRXBUSD.csv
# name:TRXBUSD.csv,
#  MAPE Open:0.013624368941597671,
#  r2 score:-0.23759030728164898
# ADAUSD.csv
# name:ADAUSD.csv,
#  MAPE Open:0.01957455059970377,
#  r2 score:0.9443350322680631
# SUKUUSD.csv
# name:SUKUUSD.csv,
#  MAPE Open:0.028766000116513975,
#  r2 score:0.3142224191437696
# ZILBUSD.csv
# name:ZILBUSD.csv,
#  MAPE Open:0.016265248768594528,
#  r2 score:0.8494941397441865
# ICXBUSD.csv
# name:ICXBUSD.csv,
#  MAPE Open:0.016012102997048028,
#  r2 score:0.7932116542350685
# SKLBUSD.csv
# name:SKLBUSD.csv,
#  MAPE Open:0.02445672374674277,
#  r2 score:0.7689943046810597
# GALAUSDT.csv
# name:GALAUSDT.csv,
#  MAPE Open:0.021507937369401053,
#  r2 score:0.8286086052180777
# FXSBUSD.csv
# name:FXSBUSD.csv,
#  MAPE Open:0.015251396173950538,
#  r2 score:0.8646456263973492
# UNIBUSD.csv
# name:UNIBUSD.csv,
#  MAPE Open:0.019327736836433657,
#  r2 score:0.8991354141785984
# FTMBUSD.csv
# name:FTMBUSD.csv,
#  MAPE Open:0.021393139551329363,
#  r2 score:0.6968000718902361
# ALPACABUSD.csv
# name:ALPACABUSD.csv,
#  MAPE Open:0.015466224057524333,
#  r2 score:0.8296253931781294
# CHZBUSD.csv
# name:CHZBUSD.csv,
#  MAPE Open:0.01732276721985541,
#  r2 score:0.7366971160505329
# STXBUSD.csv
# name:STXBUSD.csv,
#  MAPE Open:0.011332965966506086,
#  r2 score:0.8143941183291176
# JASMYUSD.csv
# name:JASMYUSD.csv,
#  MAPE Open:0.024450067162863385,
#  r2 score:0.7050491501006866
# AAVEUSD.csv
# name:AAVEUSD.csv,
#  MAPE Open:0.020937387205181755,
#  r2 score:0.8973479906486451
# SYSBUSD.csv
# name:SYSBUSD.csv,
#  MAPE Open:0.0207474090651448,
#  r2 score:0.7550989081257151
# AVAXUSD.csv
# name:AVAXUSD.csv,
#  MAPE Open:0.026746705861647374,
#  r2 score:0.7887579949990361
# ETHTUSD.csv
# name:ETHTUSD.csv,
#  MAPE Open:0.00858389684435918,
#  r2 score:0.9332545831498374
# MTLBUSD.csv
# name:MTLBUSD.csv,
#  MAPE Open:0.02378754638893204,
#  r2 score:0.6430737010014915
# CRVBUSD.csv
# name:CRVBUSD.csv,
#  MAPE Open:0.018491969634405716,
#  r2 score:0.8208239585376205

# %% [markdown]
# ## Save Data

# %%
import pickle

some_obj = [names, predicted, r, mape_vals]

with open('update2_pickle.pickle', 'wb') as f:
    pickle.dump(some_obj, f)
with open('update2_pickle.pickle', 'rb') as f:
    loaded_obj = pickle.load(f)
    
loaded_obj
# Out:
# [['LTCBUSD.csv',
#   'EGLDBUSD.csv',
#   'GALAUSD.csv',
#   'MIRBUSD.csv',
#   'CELRBUSD.csv',
#   'PYRBUSD.csv',
#   'POWRUSD.csv',
#   'XVSBUSD.csv',
#   'BNBBUSD.csv',
#   'YFIBUSD.csv',
#   'ACMBUSD.csv',
#   'EOSUSD.csv',
#   'BAKEBUSD.csv',
#   'QTUMBUSD.csv',
#   'FISBUSD.csv',
#   'ARBUSD.csv',
#   'MLNUSD.csv',
#   'COVALUSD.csv',
#   'VETBUSD.csv',
#   'ERNBUSD.csv',
#   'IOTXBUSD.csv',
#   'ELFBUSD.csv',
#   'DOTUSDT.csv',
#   'LAZIOBUSD.csv',
#   'MDTUSD.csv',
#   'LINABUSD.csv',
#   'SNXBUSD.csv',
#   'ANKRBUSD.csv',
#   'HIVEBUSD.csv',
#   'RENBUSD.csv',
#   'BICOBUSD.csv',
#   'ATOMBUSD.csv',
#   'DARBUSD.csv',
#   'POLYBUSD.csv',
#   'MATICUSD.csv',
#   'DOGEUSD.csv',
#   'RARIUSD.csv',
#   'MANAUSD.csv',
#   'COMPBUSD.csv',
#   'INJBUSD.csv',
#   'THETABUSD.csv',
#   'ZECUSD.csv',
#   'DIABUSD.csv',
#   'ALGOUSD.csv',
#   'AMPUSD.csv',
#   'CTSIBUSD.csv',
#   'FTTBUSD.csv',
#   'CELOBUSD.csv',
#   'BADGERBUSD.csv',
#   'RENUSD.csv',
#   'BALUSD.csv',
#   'NKNUSD.csv',
#   'OOKIBUSD.csv',
#   'BADGERUSD.csv',
#   'DYDXBUSD.csv',
#   'SOLBUSD.csv',
#   'LPTUSD.csv',
#   'CROUSD.csv',
#   'ZRXBUSD.csv',
#   'JSTBUSD.csv',
#   'HNTBUSD.csv',
#   'BCHUSD.csv',
#   'ETHUSD.csv',
#   'KRLUSD.csv',
#   'BATUSD.csv',
#   'AERGOBUSD.csv',
#   'PLAUSD.csv',
#   'AVAXUSDT.csv',
#   'HIGHBUSD.csv',
#   'BCHBUSD.csv',
#   'ICPUSD.csv',
#   'FETUSD.csv',
#   'ENSUSD.csv',
#   'FARMUSD.csv',
#   'MDXBUSD.csv',
#   'CGLDUSD.csv',
#   'KP3RBUSD.csv',
#   'NUUSD.csv',
#   'API3USD.csv',
#   'BNBTUSD.csv',
#   'GRTBUSD.csv',
#   'WRXBUSD.csv',
#   'ZECBUSD.csv',
#   'GTCBUSD.csv',
#   'BONDBUSD.csv',
#   'AUCTIONUSD.csv',
#   'MANABUSD.csv',
#   'CHESSBUSD.csv',
#   'PERPBUSD.csv',
#   'ONTBUSD.csv',
#   'SCRTBUSD.csv',
#   'BALBUSD.csv',
#   'POLYUSD.csv',
#   'PEOPLEBUSD.csv',
#   'SOLUSDT.csv',
#   'CTXCBUSD.csv',
#   'LTCUSD.csv',
#   'USDTEUR.csv',
#   'ENJBUSD.csv',
#   'FILBUSD.csv',
#   'LINKBUSD.csv',
#   'POLSBUSD.csv',
#   'GRTUSD.csv',
#   'SOLUSD.csv',
#   'REQBUSD.csv',
#   'IOTXUSD.csv',
#   'SUPERBUSD.csv',
#   'ATOMUSD.csv',
#   'BETABUSD.csv',
#   'SUSHIUSD.csv',
#   'CFXBUSD.csv',
#   'DASHBUSD.csv',
#   'FORBUSD.csv',
#   'GTCUSD.csv',
#   'OMGBUSD.csv',
#   'AVAXBUSD.csv',
#   'OGNBUSD.csv',
#   'RVNBUSD.csv',
#   'NEARBUSD.csv',
#   'ADXBUSD.csv',
#   'AAVEBUSD.csv',
#   'LRCBUSD.csv',
#   'SUSHIBUSD.csv',
#   'MBOXBUSD.csv',
#   'FORTHBUSD.csv',
#   'MASKUSD.csv',
#   'BIFIBUSD.csv',
#   'JASMYBUSD.csv',
#   'DESOUSD.csv',
#   'MOVRBUSD.csv',
#   'RUNEBUSD.csv',
#   'SNXUSD.csv',
#   'PROMBUSD.csv',
#   'KEEPUSD.csv',
#   'FIDABUSD.csv',
#   'ALPHABUSD.csv',
#   'JOEBUSD.csv',
#   'FOXUSD.csv',
#   'ALCXUSD.csv',
#   'UFTBUSD.csv',
#   'ATABUSD.csv',
#   'ARPAUSD.csv',
#   'BANDUSD.csv',
#   'QNTBUSD.csv',
#   'DOGEBUSD.csv',
#   'ROSEBUSD.csv',
#   'DASHUSD.csv',
#   'QIBUSD.csv',
#   'CITYBUSD.csv',
#   'DOTBUSD.csv',
#   'VOXELBUSD.csv',
#   'OMGUSD.csv',
#   'IOSTBUSD.csv',
#   'FRONTBUSD.csv',
#   'CVPBUSD.csv',
#   'FORTHUSD.csv',
#   'TRUUSD.csv',
#   'KNCBUSD.csv',
#   'KSMBUSD.csv',
#   'DODOBUSD.csv',
#   'PONDBUSD.csv',
#   'SLPBUSD.csv',
#   'STORJUSD.csv',
#   'TRIBEBUSD.csv',
#   'TRACUSD.csv',
#   'XRPBUSD.csv',
#   'OMBUSD.csv',
#   'ADABUSD.csv',
#   'ONEBUSD.csv',
#   'LCXUSD.csv',
#   'MASKBUSD.csv',
#   'WAXPBUSD.csv',
#   'TVKBUSD.csv',
#   'FXUSD.csv',
#   'YGGBUSD.csv',
#   'AUDBUSD.csv',
#   'UNFIBUSD.csv',
#   'COSBUSD.csv',
#   'IDEXUSD.csv',
#   'XLMUSD.csv',
#   'BTCUSD.csv',
#   'AGLDBUSD.csv',
#   'ASMUSD.csv',
#   'BATBUSD.csv',
#   'SFPBUSD.csv',
#   'RLYUSD.csv',
#   'MIRUSD.csv',
#   'KLAYBUSD.csv',
#   'KNCUSD.csv',
#   'RAMPBUSD.csv',
#   'AXSBUSD.csv',
#   'ACHUSD.csv',
#   'NEOBUSD.csv',
#   'MATICBUSD.csv',
#   'GALABUSD.csv',
#   'BELBUSD.csv',
#   'ANTBUSD.csv',
#   'FLUXBUSD.csv',
#   'VIDTBUSD.csv',
#   'RSRBUSD.csv',
#   'XLMBUSD.csv',
#   'SKLUSD.csv',
#   'COCOSBUSD.csv',
#   'SRMBUSD.csv',
#   'RAYBUSD.csv',
#   'YFIUSD.csv',
#   'CTSIUSD.csv',
#   'ENJUSD.csv',
#   'CAKEBUSD.csv',
#   'WAVESBUSD.csv',
#   'ENSBUSD.csv',
#   'CVXBUSD.csv',
#   'EOSBUSD.csv',
#   'XTZBUSD.csv',
#   'LINKUSD.csv',
#   'RLCUSD.csv',
#   'VGXUSD.csv',
#   'COMPUSD.csv',
#   'COTIBUSD.csv',
#   'RAREBUSD.csv',
#   'SXPBUSD.csv',
#   'ETHUSDT.csv',
#   'ETHUSDC.csv',
#   'BTCUSDC.csv',
#   'MCBUSD.csv',
#   'GODSUSD.csv',
#   'BTCUSDT.csv',
#   'OXTUSD.csv',
#   'CRVUSD.csv',
#   'ETCBUSD.csv',
#   'BONDUSD.csv',
#   'WBTCUSD.csv',
#   'MKRBUSD.csv',
#   'C98BUSD.csv',
#   'AXSUSD.csv',
#   'SANDBUSD.csv',
#   'MINABUSD.csv',
#   'RADUSD.csv',
#   'ILVBUSD.csv',
#   'BNXBUSD.csv',
#   'ANKRUSD.csv',
#   'AGLDUSD.csv',
#   'XYOUSD.csv',
#   'QUICKUSD.csv',
#   'RBNUSD.csv',
#   'CTKBUSD.csv',
#   'SHIBUSD.csv',
#   'ICPUSDT.csv',
#   '1INCHUSD.csv',
#   'KAVABUSD.csv',
#   'BLZUSD.csv',
#   'STORJBUSD.csv',
#   'ETHBUSD.csv',
#   'OCEANBUSD.csv',
#   'AVABUSD.csv',
#   'CLVBUSD.csv',
#   'DOTUSD.csv',
#   'TLMBUSD.csv',
#   'ORNUSD.csv',
#   '1INCHBUSD.csv',
#   'BICOUSD.csv',
#   'IDEXBUSD.csv',
#   'TRXTUSD.csv',
#   'TWTBUSD.csv',
#   'SHIBBUSD.csv',
#   'RNDRBUSD.csv',
#   'OGNUSD.csv',
#   'FLOWBUSD.csv',
#   'ALGOBUSD.csv',
#   'UMAUSD.csv',
#   'TKOBUSD.csv',
#   'IMXUSD.csv',
#   'BURGERBUSD.csv',
#   'ICPBUSD.csv',
#   'TOMOBUSD.csv',
#   'FILUSD.csv',
#   'COTIUSD.csv',
#   'HBARBUSD.csv',
#   'AUDIOBUSD.csv',
#   'MDTBUSD.csv',
#   'QNTUSD.csv',
#   'ZRXUSD.csv',
#   'PERPUSD.csv',
#   'XMRBUSD.csv',
#   'BTCBUSD.csv',
#   'CHRBUSD.csv',
#   'TORNBUSD.csv',
#   'AMPBUSD.csv',
#   'BTCTUSD.csv',
#   'CREAMBUSD.csv',
#   'ZENBUSD.csv',
#   'LRCUSD.csv',
#   'IOTABUSD.csv',
#   'BANDBUSD.csv',
#   'LITBUSD.csv',
#   'CVCUSD.csv',
#   'STRAXBUSD.csv',
#   'USDCEUR.csv',
#   'FARMBUSD.csv',
#   'ARPABUSD.csv',
#   'REQUSD.csv',
#   'ALICEBUSD.csv',
#   'ETCUSD.csv',
#   'NMRUSD.csv',
#   'DFBUSD.csv',
#   'MKRUSD.csv',
#   'UNIUSD.csv',
#   'XTZUSD.csv',
#   'TRXBUSD.csv',
#   'ADAUSD.csv',
#   'SUKUUSD.csv',
#   'ZILBUSD.csv',
#   'ICXBUSD.csv',
#   'SKLBUSD.csv',
#   'GALAUSDT.csv',
#   'FXSBUSD.csv',
#   'UNIBUSD.csv',
#   'FTMBUSD.csv',
#   'ALPACABUSD.csv',
#   'CHZBUSD.csv',
#   'STXBUSD.csv',
#   'JASMYUSD.csv',
#   'AAVEUSD.csv',
#   'SYSBUSD.csv',
#   'AVAXUSD.csv',
#   'ETHTUSD.csv',
#   'MTLBUSD.csv',
#   'CRVBUSD.csv'],
#  [array([[62. , 62. , 60.4, 61.4],
#          [61.4, 63.3, 61. , 63.2],
#          [63.2, 63.3, 61.6, 61.5],
#          [62.1, 62.6, 61.5, 61.7],
#          [62.3, 63.1, 61.7, 62.3],
#          [62.4, 61.9, 62.1, 61.7],
#          [63.2, 63.6, 62.6, 62.6],
#          [61.8, 62.5, 62.5, 63.4],
#          [63.5, 63.1, 63. , 62.6],
#          [61.7, 62.5, 61.6, 62.2],
#          [61.8, 62.5, 61.7, 62.3],
#          [63.4, 63.2, 63.1, 62.9],
#          [62.6, 63.3, 62.3, 62.8],
#          [63.1, 63.7, 62.3, 63.4],
#          [64.6, 64.3, 63.9, 64.3],
#          [63.7, 63.7, 62.5, 63.1],
#          [63.8, 64.8, 63.7, 64.2],
#          [63.3, 63.1, 62.8, 62.8],
#          [62.9, 63.7, 62.4, 63.4],
#          [62.5, 63.1, 62.8, 63.3],
#          [63.7, 63.4, 63.1, 63.2],
#          [63.5, 63. , 62.7, 63. ],
#          [63.2, 63.3, 62.2, 62.9],
#          [62.6, 62.7, 62.3, 62.1],
#          [63. , 63. , 63.2, 62.4],
#          [63.9, 63.4, 63.5, 63.6],
#          [62.4, 63. , 62. , 62.4],
#          [62.1, 62.6, 61.7, 62.6],
#          [60.9, 61.5, 61.3, 61.9],
#          [60.6, 61.4, 60.6, 60.8],
#          [62. , 62.9, 62.2, 62.6],
#          [62.2, 62.5, 62.5, 62.6],
#          [63.2, 62.8, 62.6, 62.6],
#          [62.2, 62.3, 61.6, 61.7],
#          [63. , 63.4, 62.8, 63.1],
#          [62.9, 64. , 63. , 63.5],
#          [64.5, 64. , 64. , 64.3],
#          [63.3, 65.1, 63.8, 65.4],
#          [65. , 65.3, 64.1, 65. ],
#          [64.9, 65. , 64.4, 64.8],
#          [64.4, 64.5, 63.9, 64.4],
#          [62.4, 63.4, 62.7, 63.6],
#          [64.3, 64.1, 63.7, 63.7],
#          [64.5, 64.5, 63.1, 63.5],
#          [63.5, 63.9, 63.2, 64. ],
#          [63.5, 63.4, 63.2, 63.1],
#          [63.6, 64.1, 64.3, 64. ],
#          [61.9, 63.7, 61.8, 64.3],
#          [64.2, 64.9, 64.2, 64.1],
#          [64.1, 63.3, 63.6, 63. ],
#          [64.1, 65. , 63.6, 64.7],
#          [65.3, 66.3, 65.2, 66.2],
#          [67. , 67.2, 65.9, 66.4],
#          [64.6, 65. , 64.4, 65. ],
#          [66.1, 67.3, 67. , 67.2],
#          [66. , 68.1, 65.8, 68.1],
#          [67.9, 67.5, 67.3, 67.3],
#          [67.3, 68. , 67.1, 67.1],
#          [66.7, 66.5, 65.6, 65.8],
#          [65.9, 65.9, 65. , 65. ],
#          [64.9, 65.5, 65.4, 65.5],
#          [65.1, 65.9, 64.7, 65.8],
#          [66.6, 66.7, 65.7, 66.7],
#          [66.8, 66.7, 66.6, 66. ],
#          [66.2, 66.8, 66.5, 66.5],
#          [66.4, 66.8, 65.7, 66.2],
#          [67.1, 67.6, 66.5, 67.3],
#          [66.7, 67.1, 65.9, 67.3],
#          [66.5, 66.7, 65.9, 66. ],
#          [66.5, 67.6, 65.9, 67.2],
#          [67.2, 69.1, 67.4, 68.5],
#          [69.7, 69.3, 69.1, 69.2],
#          [70.3, 71.8, 69.9, 71.1],
#          [69. , 70.8, 68.7, 70.2],
#          [69.1, 68.8, 68.2, 68.6],
#          [68.7, 69.2, 68.4, 69.3],
#          [69.9, 70.3, 69.5, 69.6],
#          [69.9, 69.3, 69.1, 68.9],
#          [69.1, 69.1, 68.6, 69.4],
#          [69.1, 69.2, 67.9, 68. ],
#          [0.01803, 0.01839, 0.0179 , 0.01835],
#          [0.01883, 0.01905, 0.01838, 0.01872],
#          [0.0191 , 0.01939, 0.01889, 0.01937],
#          [0.01904, 0.01943, 0.01928, 0.01991],
#          [0.01943, 0.01925, 0.01865, 0.01857],
#          [0.01855, 0.01897, 0.01853, 0.01886],
#          [0.01872, 0.01891, 0.0188 , 0.01878],
#          [0.0195 , 0.01973, 0.01932, 0.01917],
#          [0.01914, 0.01977, 0.01927, 0.01984],
#          [0.02021, 0.02006, 0.01968, 0.01972],
#          [0.01942, 0.0194 , 0.01863, 0.01914],
#          [0.01921, 0.01931, 0.01911, 0.01944],
#          [0.01934, 0.01945, 0.01922, 0.01946]]),
#   array([[3.89, 3.82, 3.7 , 3.79],
#          [3.8 , 3.96, 3.79, 3.99],
#          [4.  , 4.  , 3.89, 3.83],
#          [3.81, 3.74, 3.66, 3.6 ],
#          [3.75, 3.73, 3.65, 3.66],
#          [3.82, 3.76, 3.74, 3.69],
#          [3.95, 4.14, 3.96, 3.98],
#          [4.01, 4.07, 3.98, 3.97],
#          [3.99, 3.96, 3.89, 3.92],
#          [3.98, 4.07, 3.95, 3.96],
#          [3.84, 3.89, 3.82, 3.86],
#          [3.96, 3.96, 3.91, 3.91],
#          [3.84, 3.93, 3.84, 3.86],
#          [3.85, 4.1 , 3.86, 3.99],
#          [3.93, 4.07, 3.95, 3.95],
#          [4.02, 4.08, 3.96, 4.  ],
#          [3.91, 3.97, 3.94, 3.95],
#          [3.96, 3.98, 3.92, 3.96],
#          [3.96, 3.94, 3.91, 3.92],
#          [3.92, 4.02, 3.97, 4.06],
#          [4.08, 4.32, 4.03, 4.16],
#          [4.18, 4.16, 4.12, 4.12],
#          [4.19, 4.15, 4.1 , 4.09],
#          [4.  , 3.98, 3.89, 3.9 ],
#          [3.89, 3.99, 3.95, 3.97],
#          [3.95, 3.99, 3.98, 3.98],
#          [3.96, 3.95, 3.88, 3.9 ],
#          [3.89, 3.87, 3.81, 3.82],
#          [3.85, 3.86, 3.82, 3.84],
#          [3.87, 3.86, 3.83, 3.85],
#          [3.85, 3.89, 3.88, 3.91],
#          [3.94, 3.93, 3.88, 3.91],
#          [3.95, 3.93, 3.89, 3.91],
#          [4.08, 4.09, 4.03, 4.03],
#          [4.05, 3.92, 3.98, 3.93],
#          [4.07, 4.1 , 4.04, 4.05],
#          [3.99, 4.05, 4.01, 4.05],
#          [4.13, 4.2 , 4.05, 4.13],
#          [3.99, 4.05, 4.03, 4.04],
#          [4.09, 4.11, 4.05, 4.06],
#          [3.97, 4.05, 3.89, 4.04],
#          [4.15, 4.31, 4.02, 4.07],
#          [4.1 , 4.06, 4.11, 3.98],
#          [4.1 , 4.05, 4.09, 3.96],
#          [4.08, 4.03, 4.08, 3.99],
#          [4.05, 4.06, 4.02, 4.07],
#          [4.06, 4.22, 4.09, 4.16],
#          [4.09, 4.14, 4.08, 4.17],
#          [4.2 , 4.24, 4.16, 4.21],
#          [4.13, 4.14, 4.09, 4.11],
#          [4.14, 4.33, 4.16, 4.35],
#          [4.27, 4.32, 4.25, 4.29],
#          [4.23, 4.22, 4.16, 4.18],
#          [4.2 , 4.24, 4.24, 4.26],
#          [4.32, 4.43, 4.3 , 4.42],
#          [4.43, 4.57, 4.42, 4.49],
#          [4.47, 4.56, 4.36, 4.53],
#          [4.7 , 4.91, 4.57, 4.66],
#          [4.48, 4.54, 4.37, 4.42],
#          [4.24, 4.18, 4.03, 4.08],
#          [4.31, 4.36, 4.32, 4.35],
#          [4.49, 4.53, 4.37, 4.41],
#          [4.33, 4.38, 4.27, 4.35],
#          [4.41, 4.54, 4.36, 4.49],
#          [4.5 , 4.57, 4.47, 4.53],
#          [4.56, 4.72, 4.51, 4.56],
#          [4.45, 4.55, 4.49, 4.55],
#          [4.49, 4.44, 4.37, 4.45],
#          [4.41, 4.49, 4.32, 4.37],
#          [4.47, 4.59, 4.41, 4.55],
#          [4.73, 4.72, 4.66, 4.59],
#          [4.65, 4.76, 4.66, 4.75],
#          [4.68, 4.69, 4.6 , 4.64],
#          [4.75, 4.75, 4.71, 4.63],
#          [4.6 , 4.75, 4.62, 4.66],
#          [4.74, 4.92, 4.71, 4.78],
#          [4.76, 4.89, 4.66, 4.77],
#          [4.66, 4.71, 4.61, 4.73],
#          [4.74, 4.69, 4.59, 4.63],
#          [4.56, 4.73, 4.43, 4.61],
#          [4.52, 4.6 , 4.51, 4.55],
#          [4.56, 4.72, 4.53, 4.57],
#          [4.58, 4.55, 4.5 , 4.56],
#          [4.64, 4.56, 4.54, 4.56],
#          [4.68, 4.66, 4.6 , 4.66],
#          [4.66, 4.71, 4.58, 4.58],
#          [4.59, 4.73, 4.41, 4.44],
#          [4.45, 4.58, 4.21, 4.33],
#          [4.56, 4.54, 4.42, 4.59],
#          [4.63, 4.64, 4.53, 4.65],
#          [4.63, 4.61, 4.52, 4.64],
#          [4.7 , 4.73, 4.6 , 4.56],
#          [4.52, 4.74, 4.44, 4.44],
#          [4.32, 4.51, 4.35, 4.59],
#          [4.6 , 4.69, 4.57, 4.68],
#          [4.66, 4.68, 4.6 , 4.58],
#          [4.55, 4.57, 4.47, 4.46],
#          [4.5 , 4.55, 4.36, 4.57],
#          [4.54, 4.53, 4.52, 4.61],
#          [4.58, 4.53, 4.39, 4.31]]),
#   array([[0.2446, 0.244 , 0.2409, 0.2423],
#          [0.2426, 0.2504, 0.2437, 0.2505],
#          [0.2494, 0.2488, 0.2461, 0.2455],
#          [0.2543, 0.2522, 0.2527, 0.249 ],
#          [0.2473, 0.2543, 0.2482, 0.2525],
#          [0.2584, 0.2629, 0.2527, 0.254 ],
#          [0.2579, 0.2653, 0.2536, 0.257 ],
#          [0.2525, 0.2505, 0.2434, 0.2425],
#          [0.2471, 0.2463, 0.2428, 0.2422],
#          [0.2454, 0.2478, 0.243 , 0.2461],
#          [0.2469, 0.2508, 0.2486, 0.2522],
#          [0.2448, 0.2487, 0.2459, 0.2501],
#          [0.256 , 0.2544, 0.2538, 0.2545],
#          [0.2689, 0.2699, 0.2702, 0.2712],
#          [0.2726, 0.2725, 0.2744, 0.2727],
#          [0.272 , 0.2728, 0.2725, 0.2727],
#          [0.2709, 0.2708, 0.2715, 0.2717],
#          [0.2722, 0.2748, 0.2715, 0.2729],
#          [0.2771, 0.2783, 0.277 , 0.2785],
#          [0.2797, 0.2805, 0.2792, 0.2812],
#          [0.2764, 0.2781, 0.2734, 0.2776],
#          [0.2735, 0.2759, 0.2724, 0.2756],
#          [0.2794, 0.281 , 0.2738, 0.2751],
#          [0.2758, 0.2781, 0.2732, 0.2769],
#          [0.2772, 0.282 , 0.2778, 0.2819],
#          [0.2838, 0.2846, 0.2804, 0.2806],
#          [0.2802, 0.2821, 0.2784, 0.2785],
#          [0.2812, 0.2857, 0.2793, 0.2819],
#          [0.281 , 0.2824, 0.2764, 0.2781],
#          [0.2777, 0.2804, 0.2779, 0.2811],
#          [0.2805, 0.2815, 0.2802, 0.2824],
#          [0.2825, 0.2797, 0.2779, 0.2755],
#          [0.2771, 0.2788, 0.277 , 0.2788],
#          [0.2778, 0.2808, 0.2793, 0.2798],
#          [0.2763, 0.2774, 0.2746, 0.2762],
#          [0.2779, 0.2803, 0.2712, 0.2729],
#          [0.2638, 0.2704, 0.2653, 0.2706],
#          [0.2702, 0.2758, 0.2745, 0.2833],
#          [0.2831, 0.2844, 0.2794, 0.2824],
#          [0.282 , 0.2819, 0.2804, 0.2819],
#          [0.2819, 0.2802, 0.2764, 0.2738],
#          [0.2733, 0.2764, 0.2747, 0.2764],
#          [0.275 , 0.2786, 0.2764, 0.2781],
#          [0.2773, 0.2808, 0.2801, 0.2842]]),
#   array([[4.2 , 4.2 , 4.16, 4.16],
#          [4.19, 4.25, 4.19, 4.24],
#          [4.27, 4.33, 4.21, 4.26],
#          [4.18, 4.36, 4.18, 4.15],
#          [4.2 , 4.24, 4.24, 4.32],
#          [4.38, 4.34, 4.34, 4.43],
#          [4.38, 4.71, 4.39, 4.43],
#          [4.41, 4.37, 4.39, 4.38],
#          [4.41, 4.37, 4.39, 4.37],
#          [4.4 , 4.39, 4.39, 4.4 ],
#          [4.42, 4.31, 4.39, 4.37],
#          [4.43, 4.26, 4.34, 4.34],
#          [4.39, 4.26, 4.37, 4.39],
#          [4.43, 4.54, 4.42, 4.48],
#          [4.51, 4.67, 4.49, 4.49],
#          [4.51, 4.43, 4.44, 4.5 ],
#          [4.37, 4.46, 4.36, 4.34],
#          [4.36, 4.39, 4.4 , 4.47],
#          [4.37, 4.38, 4.38, 4.43],
#          [4.35, 4.37, 4.4 , 4.45],
#          [4.48, 4.42, 4.46, 4.52],
#          [4.39, 4.42, 4.42, 4.43],
#          [4.41, 4.41, 4.41, 4.41],
#          [4.41, 4.42, 4.39, 4.4 ],
#          [4.47, 4.65, 4.47, 4.5 ],
#          [4.46, 4.66, 4.4 , 4.57],
#          [4.63, 4.5 , 4.57, 4.57],
#          [4.75, 4.78, 4.66, 4.67],
#          [4.43, 4.42, 4.45, 4.46],
#          [4.71, 4.75, 4.64, 4.7 ],
#          [4.56, 4.64, 4.57, 4.57],
#          [4.57, 4.78, 4.52, 4.69],
#          [4.52, 4.49, 4.48, 4.46],
#          [4.58, 4.77, 4.57, 4.6 ],
#          [4.47, 4.5 , 4.45, 4.47],
#          [4.51, 4.53, 4.49, 4.56],
#          [4.54, 4.56, 4.52, 4.54],
#          [4.55, 4.57, 4.52, 4.54],
#          [4.51, 4.53, 4.51, 4.53],
#          [4.56, 4.78, 4.55, 4.73],
#          [4.55, 4.55, 4.48, 4.46],
#          [4.54, 4.53, 4.51, 4.5 ],
#          [4.52, 4.52, 4.49, 4.52],
#          [4.55, 4.56, 4.52, 4.5 ],
#          [4.55, 4.82, 4.52, 4.73],
#          [4.65, 4.7 , 4.56, 4.61],
#          [4.65, 4.62, 4.58, 4.59],
#          [4.6 , 4.67, 4.64, 4.7 ],
#          [4.71, 4.73, 4.66, 4.64],
#          [4.77, 4.67, 4.69, 4.62],
#          [4.52, 4.61, 4.54, 4.65],
#          [4.79, 5.05, 4.82, 4.98],
#          [4.79, 4.97, 4.76, 4.94],
#          [5.22, 5.37, 5.01, 4.92],
#          [4.91, 5.19, 4.89, 4.99],
#          [4.93, 4.98, 4.93, 4.95],
#          [4.96, 5.02, 4.87, 4.86],
#          [4.97, 5.02, 4.95, 4.96],
#          [4.91, 4.99, 4.9 , 4.86],
#          [4.91, 4.93, 4.9 , 4.92],
#          [4.9 , 4.95, 4.9 , 4.94],
#          [4.94, 4.95, 4.72, 4.72],
#          [4.75, 4.73, 4.67, 4.69],
#          [4.73, 4.78, 4.7 , 4.7 ],
#          [4.64, 4.72, 4.75, 4.83],
#          [4.85, 4.81, 4.77, 4.86],
#          [4.81, 4.77, 4.75, 4.74],
#          [4.76, 4.76, 4.73, 4.73],
#          [4.72, 4.82, 4.76, 4.85],
#          [4.73, 4.89, 4.79, 4.92],
#          [4.97, 5.06, 4.94, 5.  ],
#          [5.21, 5.33, 5.08, 5.08],
#          [5.05, 5.01, 4.93, 4.92],
#          [4.96, 5.12, 4.95, 5.13],
#          [4.92, 4.98, 4.9 , 5.05],
#          [4.92, 5.06, 4.95, 5.09],
#          [5.2 , 5.19, 5.14, 5.1 ],
#          [5.06, 5.08, 5.  , 4.97],
#          [5.06, 4.83, 4.96, 4.9 ],
#          [4.93, 4.92, 4.8 , 4.82],
#          [4.81, 4.86, 4.8 , 4.88],
#          [4.86, 4.92, 4.97, 5.  ],
#          [4.94, 4.95, 4.86, 4.83],
#          [4.69, 4.7 , 4.63, 4.69],
#          [4.91, 4.93, 4.94, 5.02],
#          [4.92, 4.92, 4.95, 5.  ],
#          [4.95, 5.07, 4.85, 4.85],
#          [4.95, 5.13, 4.96, 5.09],
#          [5.06, 5.28, 5.07, 5.27],
#          [5.26, 5.29, 5.19, 5.18],
#          [5.07, 5.15, 5.05, 5.22],
#          [5.1 , 5.14, 4.98, 4.97],
#          [4.9 , 5.  , 4.98, 5.  ],
#          [5.06, 5.09, 5.04, 5.03],
#          [4.96, 4.97, 4.96, 5.01],
#          [4.96, 4.98, 4.97, 5.03],
#          [5.03, 5.04, 5.03, 5.04],
#          [5.03, 5.09, 4.96, 5.  ],
#          [5.06, 5.05, 5.03, 5.02],
#          [5.06, 5.02, 4.92, 4.89]]),
#   array([[305.2, 305.8, 297.8, 301. ],
#          [301.1, 305.7, 298.8, 305.7],
#          [304.2, 305.8, 297.5, 300.1],
#          [296.4, 298.4, 292.8, 292.2],
#          [292.3, 298.3, 295.1, 302.6],
#          [298.3, 299.8, 296. , 296. ],
#          [303.9, 305.4, 303.6, 306.1],
#          [304.1, 303.7, 302.8, 302.3],
#          [299.7, 300. , 297.2, 295.7],
#          [302. , 301.9, 299.9, 299.7],
#          [300.4, 300.7, 299.7, 299.5],
#          [298.1, 300.4, 298.9, 301.8],
#          [301.7, 304.6, 301.5, 303.6],
#          [301.2, 303.9, 299.6, 301.8],
#          [305.6, 309.5, 304.7, 307.9],
#          [308.7, 307.8, 307.2, 306. ],
#          [305.7, 308.7, 305.8, 309.1],
#          [308.8, 310.9, 307.7, 307.3],
#          [307.2, 306.5, 304.6, 303.3],
#          [303.6, 306.9, 304.3, 308.5],
#          [308.6, 308.6, 306.2, 306.6],
#          [311.7, 310.5, 308.9, 309.5],
#          [309.6, 308.6, 308.3, 307.1],
#          [309. , 307.9, 307.9, 306.2],
#          [310.1, 311.5, 308.7, 308.3],
#          [306.5, 306.9, 304.9, 304.1],
#          [304.3, 301.7, 297.8, 299.8],
#          [300.1, 299.4, 296.1, 297.4],
#          [297.4, 297.1, 295.7, 297.3],
#          [297.6, 298.2, 296. , 296.7],
#          [296.1, 298. , 296.4, 298.2],
#          [300.8, 301.5, 300.5, 302.5],
#          [300.9, 301.3, 300.9, 302.4],
#          [300.7, 305.2, 300.8, 302. ],
#          [302.2, 303.2, 299.4, 299.1],
#          [299.3, 301.8, 299.7, 302.2],
#          [302.5, 303.5, 303.2, 305.1],
#          [305.2, 308.9, 304.5, 308.2],
#          [308. , 311. , 307. , 306.5],
#          [307.5, 309.4, 305.7, 305.3],
#          [301.8, 299.9, 298.8, 301.3],
#          [305.9, 308.8, 305.4, 305.4],
#          [303.6, 306. , 303.1, 303.3],
#          [303.3, 302.1, 301.2, 301.8],
#          [301.7, 301.3, 300.5, 301.3],
#          [301.1, 302.8, 301.3, 302.6],
#          [302.8, 304. , 302.2, 304.6],
#          [304.7, 311.9, 304.4, 308.6],
#          [308.5, 309.7, 308.4, 307.8],
#          [308.5, 309. , 306.9, 306.5],
#          [304.5, 311.5, 304.6, 312. ],
#          [311.1, 316.1, 310.1, 314.5],
#          [313.8, 317.6, 314. , 317. ],
#          [319.6, 320.5, 318.1, 319.6],
#          [317. , 318.8, 318. , 320.4],
#          [318.4, 325.3, 318.4, 323.4],
#          [319.1, 319.6, 317.6, 319.7],
#          [319.3, 322.1, 318.7, 319.1],
#          [317.4, 317.3, 312.8, 312.3],
#          [317.5, 317. , 315.8, 315.4],
#          [316.9, 317.8, 316.1, 317.1],
#   array([0.01120502, 0.01207917, 0.01074091, 0.01083558]),
#   array([0.01163033, 0.01021823, 0.0112057 , 0.01088181]),
#   array([0.01098416, 0.01450611, 0.01013165, 0.00996638]),
#   array([0.02106699, 0.01639185, 0.01852295, 0.01915091]),
#   array([0.0107293 , 0.01770945, 0.01335513, 0.01389828]),
#   array([0.01380981, 0.01365329, 0.01194779, 0.01332035]),
#   array([0.0275322 , 0.02730508, 0.02418233, 0.0265522 ]),
#   array([0.01799766, 0.02143521, 0.01927405, 0.01937593]),
#   array([0.01153755, 0.0133794 , 0.01006316, 0.01191176]),
#   array([0.02227198, 0.02096089, 0.0215166 , 0.02071587]),
#   array([0.02048264, 0.02806755, 0.01951558, 0.02262515]),
#   array([0.02477586, 0.02183993, 0.02254116, 0.02257021]),
#   array([0.0209198 , 0.02618408, 0.02102637, 0.02367427]),
#   array([0.01019969, 0.01040857, 0.01074981, 0.01195115]),
#   array([0.01914976, 0.01879677, 0.01813178, 0.01718056]),
#   array([0.02703352, 0.02852041, 0.02098006, 0.02530425]),
#   array([0.01202659, 0.01269906, 0.01372755, 0.01242721]),
#   array([0.0238657 , 0.02261043, 0.0227066 , 0.02217961]),
#   array([0.00987922, 0.00957511, 0.00944293, 0.00973775]),
#   array([0.02187981, 0.01923784, 0.02000963, 0.01997212]),
#   array([0.01569855, 0.01540542, 0.01445208, 0.01801933]),
#   array([0.01737681, 0.01384622, 0.01525686, 0.0155763 ]),
#   array([0.03608791, 0.03414901, 0.02942901, 0.03140661]),
#   array([0.01355923, 0.01809484, 0.01083129, 0.01409559]),
#   array([0.02624436, 0.03650435, 0.0167399 , 0.0298271 ]),
#   array([0.01826606, 0.01654378, 0.01820305, 0.01615153]),
#   array([0.02340451, 0.03663505, 0.01847659, 0.02589417]),
#   array([0.03350095, 0.03492766, 0.03011847, 0.03229405]),
#   array([0.01436828, 0.01313906, 0.01527268, 0.01533675]),
#   array([0.01732988, 0.01603788, 0.01805121, 0.01703088]),
#   array([0.02501279, 0.01977875, 0.02468178, 0.02493192]),
#   array([0.01267034, 0.01340963, 0.01164555, 0.0129021 ]),
#   array([0.03763003, 0.03696222, 0.03146414, 0.03269135]),
#   array([0.01817455, 0.01878705, 0.01947117, 0.01845316]),
#   array([0.02524717, 0.04053482, 0.02359266, 0.02862559]),
#   array([0.01117674, 0.010202  , 0.01149347, 0.01107171]),
#   array([0.00078879, 0.00077541, 0.00070038, 0.00078763]),
#   array([0.01595745, 0.01764533, 0.01669763, 0.01895011]),
#   array([0.01486348, 0.01543054, 0.01427774, 0.01608124]),
#   array([0.01595288, 0.01717154, 0.01504316, 0.01652764]),
#   array([0.01419677, 0.01255977, 0.01307695, 0.01245205]),
#   array([0.02076915, 0.01889306, 0.01933792, 0.02098327]),
#   array([0.01807149, 0.0182587 , 0.01885609, 0.01834867]),
#   array([0.01927526, 0.01980318, 0.01694225, 0.02072181]),
#   array([0.02841127, 0.02644717, 0.02655986, 0.02703482]),
#   array([0.03257568, 0.03731652, 0.02445596, 0.0263641 ]),
#   array([0.01617117, 0.01753614, 0.01656485, 0.01723524]),
#   array([0.03671079, 0.04428937, 0.02653572, 0.03825919]),
#   array([0.02031203, 0.01988494, 0.01709464, 0.01901513]),
#   array([0.01697259, 0.02068488, 0.01509952, 0.01771925]),
#   array([0.01271292, 0.01287341, 0.01357821, 0.013974  ]),
#   array([0.02030996, 0.02213893, 0.01637779, 0.01878368]),
#   array([0.0310657 , 0.03255745, 0.0284819 , 0.03451659]),
#   array([0.01614117, 0.01639726, 0.0144106 , 0.01532443]),
#   array([0.02491058, 0.02461137, 0.02354716, 0.02481286]),
#   array([0.03641279, 0.05156908, 0.0382666 , 0.03762551]),
#   array([0.01713588, 0.01577794, 0.01706955, 0.01531001]),
#   array([0.0207401 , 0.01896077, 0.01953967, 0.01873902]),
#   array([0.01087862, 0.01183163, 0.00974209, 0.01071306]),
#   array([0.02008927, 0.01937157, 0.0168081 , 0.0189512 ]),
#   array([0.02066375, 0.019627  , 0.02062913, 0.02087627]),
#   array([0.0191782 , 0.02128095, 0.01771651, 0.0218594 ]),
#   array([0.02017613, 0.01973851, 0.0171559 , 0.01847069]),
#   array([0.04722391, 0.05683652, 0.02769906, 0.04938088]),
#   array([0.02945735, 0.02247434, 0.02588353, 0.02478419]),
#   array([0.01780565, 0.02102209, 0.01689415, 0.01915006]),
#   array([0.02290117, 0.02176128, 0.02081742, 0.02158604]),
#   array([0.01519775, 0.01713859, 0.01613796, 0.01679137]),
#   array([0.01495061, 0.01350704, 0.01599437, 0.0154113 ]),
#   array([0.02597633, 0.0250812 , 0.02103295, 0.022803  ]),
#   array([0.03041535, 0.02752617, 0.0256787 , 0.03070849]),
#   array([0.01497681, 0.0189065 , 0.01244666, 0.01454639]),
#   array([0.01579238, 0.02246644, 0.01370173, 0.01758981]),
#   array([0.01654872, 0.03613347, 0.01605192, 0.01984383]),
#   array([0.02710153, 0.02956656, 0.02683255, 0.0273611 ]),
#   array([0.02801147, 0.03684109, 0.02738951, 0.02774557]),
#   array([0.02011027, 0.04158037, 0.01972965, 0.02095994]),
#   array([0.02303794, 0.02573411, 0.0214344 , 0.02564654]),
#   array([0.03131978, 0.04662987, 0.03355492, 0.03945122]),
#   array([0.02699854, 0.02517913, 0.02488013, 0.02518905]),
#   array([0.03453808, 0.03783616, 0.02990962, 0.03250601]),
#   array([0.01970646, 0.02103151, 0.01904703, 0.02119199]),
#   array([0.01620342, 0.01563489, 0.01671338, 0.01626991]),
#   array([0.01325837, 0.0160134 , 0.01138152, 0.01129219]),
#   array([0.02016701, 0.0204619 , 0.01668843, 0.01804957]),
#   array([0.01191471, 0.01235967, 0.01279474, 0.01364102]),
#   array([0.0247871 , 0.02456157, 0.01989143, 0.02647683]),
#   array([0.01671726, 0.01785214, 0.0189502 , 0.01672646]),
#   array([0.01736702, 0.01735072, 0.01659857, 0.01707108]),
#   array([0.02274931, 0.02708787, 0.01753547, 0.02069216]),
#   array([0.015512  , 0.01562776, 0.01565875, 0.01690679]),
#   array([0.01197399, 0.0117575 , 0.01230558, 0.01256213]),
#   array([0.02090087, 0.02384683, 0.01859748, 0.01912872]),
#   array([0.01685723, 0.02242213, 0.01696914, 0.01946037]),
#   array([0.04216591, 0.04825203, 0.02416739, 0.03678356]),
#   array([0.03118085, 0.04053736, 0.02561262, 0.03011775]),
#   array([0.02520398, 0.02727244, 0.02350912, 0.02549615]),
#   array([0.01940938, 0.0188733 , 0.01844419, 0.0208465 ]),
#   array([0.03993873, 0.0513056 , 0.03446375, 0.0438849 ]),
#   array([0.02312248, 0.02488073, 0.02040904, 0.02157773]),
#   array([0.01892522, 0.01929421, 0.01852085, 0.01845887]),
#   array([0.0257898 , 0.01628205, 0.01797216, 0.02278308]),
#   array([0.00933838, 0.01089812, 0.00889192, 0.00876413]),
#   array([0.02504428, 0.02787407, 0.01958677, 0.02317208]),
#   array([0.00834892, 0.00986049, 0.00779776, 0.00912478]),
#   array([0.01473061, 0.01679324, 0.01708725, 0.0160364 ]),
#   array([0.01944884, 0.02012617, 0.01795402, 0.01942325]),
#   array([0.01919011, 0.01752227, 0.01943555, 0.01931342]),
#   array([0.02275533, 0.02256732, 0.01951757, 0.02320413]),
#   array([0.02514136, 0.02465114, 0.02191873, 0.02333238]),
#   array([0.01484371, 0.01744138, 0.01407633, 0.01394777]),
#   array([0.02062219, 0.02050882, 0.01698961, 0.01840864]),
#   array([0.02125827, 0.03634097, 0.01532055, 0.01962493]),
#   array([0.02918582, 0.03920278, 0.02457703, 0.02902779]),
#   array([0.00118881, 0.00117955, 0.00119895, 0.00114962]),
#   array([0.04290734, 0.05332419, 0.03775525, 0.04003745]),
#   array([0.0151566 , 0.01885387, 0.01281532, 0.0154454 ]),
#   array([0.02784875, 0.02833205, 0.02126137, 0.02433457]),
#   array([0.01396337, 0.01071013, 0.01339973, 0.01309415]),
#   array([0.00923429, 0.00836566, 0.00843627, 0.00897793]),
#   array([0.01850539, 0.01939702, 0.01475393, 0.01530758]),
#   array([0.03380006, 0.03625502, 0.02930766, 0.03608378]),
#   array([0.01577338, 0.01488405, 0.01678644, 0.01691178]),
#   array([0.02564417, 0.02219764, 0.02406349, 0.02234416]),
#   array([0.01497156, 0.01405053, 0.01599147, 0.01426521]),
#   array([0.04375183, 0.04241236, 0.03754187, 0.03576757]),
#   array([0.01235364, 0.01103971, 0.01158361, 0.01408465]),
#   array([0.02753506, 0.02809389, 0.02307078, 0.02657615]),
#   array([0.02356834, 0.0249214 , 0.01876843, 0.01778585]),
#   array([0.02840034, 0.02869652, 0.02540245, 0.02739202]),
#   array([0.02187297, 0.02137312, 0.01889291, 0.02099144]),
#   array([0.01497391, 0.01543912, 0.01411518, 0.01407624]),
#   array([0.01830386, 0.01386659, 0.0163803 , 0.01419837]),
#   array([0.01978768, 0.02152775, 0.02103774, 0.02290911]),
#   array([0.09190414, 0.09677941, 0.08047667, 0.09403272]),
#   array([0.02859236, 0.02964069, 0.02494338, 0.026967  ]),
#   array([0.01417975, 0.0165273 , 0.01415637, 0.01465597]),
#   array([0.01932799, 0.02075254, 0.01941762, 0.01863323]),
#   array([0.03529971, 0.03611073, 0.03265687, 0.0344159 ]),
#   array([0.01416752, 0.01170928, 0.01364262, 0.01410101]),
#   array([0.01985702, 0.02934134, 0.0220448 , 0.02086736]),
#   array([0.01623067, 0.02186744, 0.01348082, 0.01438171]),
#   array([0.01867433, 0.01682531, 0.01659991, 0.01723528]),
#   array([0.01765173, 0.02062423, 0.01840189, 0.02030573]),
#   array([0.01763488, 0.0170683 , 0.01496021, 0.01584557]),
#   array([0.01817318, 0.01660116, 0.0167552 , 0.01890856]),
#   array([0.01751414, 0.01799389, 0.01707534, 0.01778   ]),
#   array([0.01182413, 0.01119333, 0.01105104, 0.01087745]),
#   array([0.04919542, 0.05944268, 0.04568949, 0.04751992]),
#   array([0.02533353, 0.02574175, 0.02569207, 0.02536162]),
#   array([0.01664388, 0.0201102 , 0.01709527, 0.01579305]),
#   array([0.01136573, 0.00997107, 0.01156954, 0.01030954]),
#   array([0.01702927, 0.01708368, 0.01657382, 0.01754241]),
#   array([0.0174439 , 0.01798476, 0.01616647, 0.01738038]),
#   array([0.0245945 , 0.02389703, 0.02172868, 0.0244392 ]),
#   array([0.0189858 , 0.02162376, 0.01842274, 0.0213973 ]),
#   array([0.01743914, 0.01947896, 0.01829807, 0.01887463]),
#   array([0.01908497, 0.01639507, 0.01708089, 0.02055559]),
#   array([0.02427445, 0.035197  , 0.02013371, 0.02627103]),
#   array([0.01346249, 0.01138792, 0.01331341, 0.01351703]),
#   array([0.01199727, 0.01165788, 0.01230234, 0.01269248]),
#   array([0.01155177, 0.01100854, 0.01153073, 0.0117883 ]),
#   array([0.00926434, 0.00848342, 0.00842592, 0.00827713]),
#   array([0.01612726, 0.0162735 , 0.01348434, 0.01702037]),
#   array([0.03868498, 0.03724908, 0.03607202, 0.03497907]),
#   array([0.00934042, 0.00815479, 0.00798371, 0.00824976]),
#   array([0.03972808, 0.04383791, 0.02270561, 0.02820237]),
#   array([0.0199248 , 0.01852396, 0.01946004, 0.01956138]),
#   array([0.01566095, 0.01293675, 0.01270715, 0.0136646 ]),
#   array([0.01686119, 0.02251798, 0.01278246, 0.01551771]),
#   array([0.00783051, 0.00881156, 0.00786063, 0.00771576]),
#   array([0.01980894, 0.01725179, 0.01910152, 0.021097  ]),
#   array([0.02316395, 0.02515987, 0.02214813, 0.02183234]),
#   array([0.03047893, 0.02794287, 0.02756417, 0.02758129]),
#   array([0.01716026, 0.0183737 , 0.01949082, 0.01980564]),
#   array([0.01953947, 0.01958546, 0.01894923, 0.02081482]),
#   array([0.02763837, 0.03779208, 0.02077002, 0.02909475]),
#   array([0.01511701, 0.01559427, 0.01401232, 0.01504622]),
#   array([0.01110081, 0.01614488, 0.0117226 , 0.01250452]),
#   array([0.01636429, 0.01571046, 0.01667983, 0.01826799]),
#   array([0.01846293, 0.01789172, 0.01678635, 0.01877712]),
#   array([0.01332526, 0.0156774 , 0.01440636, 0.01315391]),
#   array([0.01643841, 0.01656777, 0.0140617 , 0.01447041]),
#   array([0.03499106, 0.02596931, 0.02579973, 0.03610007]),
#   array([0.0172223 , 0.0187897 , 0.01607409, 0.01631932]),
#   array([0.01848944, 0.01937694, 0.01886443, 0.01776589]),
#   array([0.02034726, 0.02148916, 0.01909617, 0.02118603]),
#   array([0.01152729, 0.0106224 , 0.01024714, 0.01084788]),
#   array([0.02799188, 0.02806183, 0.02264802, 0.02386912]),
#   array([0.02490339, 0.02388037, 0.0217834 , 0.02163744]),
#   array([0.01811855, 0.0180518 , 0.01833906, 0.02032828]),
#   array([0.01032685, 0.00977957, 0.01107382, 0.01115024]),
#   array([0.02493204, 0.02307236, 0.02161309, 0.02393293]),
#   array([0.01096376, 0.01323765, 0.01067   , 0.01042978]),
#   array([0.02113685, 0.02716262, 0.02034572, 0.02289286]),
#   array([0.01803322, 0.01726771, 0.01795415, 0.01761968]),
#   array([0.0179753 , 0.0156155 , 0.01802517, 0.01676716]),
#   array([0.02719981, 0.0309501 , 0.02585901, 0.02466646]),
#   array([0.01152598, 0.01115319, 0.0105048 , 0.01038514]),
#   array([0.02679898, 0.02895059, 0.02253585, 0.02420977]),
#   array([0.02842526, 0.02588109, 0.02306667, 0.02202584]),
#   array([0.01167582, 0.01105956, 0.01118188, 0.01145552]),
#   array([0.01735274, 0.01673931, 0.01661517, 0.01716456]),
#   array([0.01792828, 0.01687925, 0.01784653, 0.01684684]),
#   array([0.02683524, 0.02705468, 0.02439672, 0.02511931]),
#   array([0.03599957, 0.04379719, 0.03649457, 0.03948432]),
#   array([0.01784449, 0.01721628, 0.01513433, 0.0157502 ]),
#   array([0.01679749, 0.01620018, 0.0148696 , 0.01670543]),
#   array([0.01519442, 0.01868611, 0.0151345 , 0.01484767]),
#   array([0.01910616, 0.02336967, 0.01415828, 0.01658986]),
#   array([0.03002877, 0.0247172 , 0.0272196 , 0.02603148]),
#   array([0.04140949, 0.05438026, 0.03350917, 0.04015246]),
#   array([0.02065644, 0.02220117, 0.01873153, 0.02012535]),
#   array([0.02708498, 0.02835605, 0.0247242 , 0.02713079]),
#   array([0.01461357, 0.01435275, 0.01422367, 0.01565462]),
#   array([0.01900263, 0.01807842, 0.01680182, 0.02094285]),
#   array([0.01712405, 0.01585842, 0.01465651, 0.01748484]),
#   array([0.02822397, 0.02462776, 0.02868602, 0.02412316]),
#   array([0.01489557, 0.0208111 , 0.01446941, 0.01640444]),
#   array([0.01710717, 0.01369434, 0.0165161 , 0.01560396]),
#   array([0.01636845, 0.01700763, 0.01542989, 0.0163625 ]),
#   array([0.03368421, 0.03098693, 0.03034819, 0.03146134]),
#   array([0.01418909, 0.0147761 , 0.01442008, 0.01491206]),
#   array([0.0080941 , 0.00796568, 0.00754461, 0.0081244 ]),
#   array([0.02919654, 0.0272892 , 0.02677645, 0.02614515]),
#   array([0.02964858, 0.03495429, 0.03198732, 0.03214012]),
#   array([0.00991792, 0.01098491, 0.01014628, 0.01161731]),
#   array([0.0078269 , 0.00701776, 0.00862758, 0.0085215 ]),
#   array([0.02782823, 0.02669717, 0.02411991, 0.02581619]),
#   array([0.01663422, 0.0157416 , 0.01613804, 0.01697482]),
#   array([0.0215904 , 0.01719969, 0.01965756, 0.02039388]),
#   array([0.01876234, 0.01543584, 0.01869312, 0.01665409]),
#   array([0.02146113, 0.01912557, 0.01868779, 0.02017317]),
#   array([0.03322843, 0.03769086, 0.02899603, 0.0280241 ]),
#   array([0.02166188, 0.01928838, 0.01787768, 0.02005259]),
#   array([0.01578423, 0.02070319, 0.01214179, 0.01350957]),
#   array([0.00069378, 0.00069222, 0.00076223, 0.00073236]),
#   array([0.01872894, 0.02288789, 0.0181103 , 0.01971681]),
#   array([0.03360025, 0.03562732, 0.02796028, 0.03185149]),
#   array([0.01994154, 0.02135803, 0.01879384, 0.02040233]),
#   array([0.02462665, 0.01995058, 0.02523469, 0.02348206]),
#   array([0.01406504, 0.01191508, 0.01229916, 0.01303497]),
#   array([0.01424484, 0.01287581, 0.01285914, 0.01204144]),
#   array([0.01708118, 0.02416088, 0.01520822, 0.01864052]),
#   array([0.02167743, 0.01874836, 0.02056137, 0.01910155]),
#   array([0.01858888, 0.01800227, 0.01837531, 0.01660598]),
#   array([0.01731539, 0.01499088, 0.01657071, 0.01643661]),
#   array([0.01237119, 0.01362437, 0.01196547, 0.01184458]),
#   array([0.01824955, 0.01957455, 0.01768565, 0.01790502]),
#   array([0.02747245, 0.028766  , 0.02409707, 0.02911534]),
#   array([0.01805842, 0.01626525, 0.01541283, 0.01757026]),
#   array([0.01728982, 0.0160121 , 0.01754466, 0.01718294]),
#   array([0.02240798, 0.02445672, 0.02433499, 0.02477087]),
#   array([0.02185361, 0.02150794, 0.02196946, 0.02264252]),
#   array([0.01191739, 0.0152514 , 0.01111537, 0.01144418]),
#   array([0.01832642, 0.01932774, 0.01754352, 0.02088432]),
#   array([0.0245566 , 0.02139314, 0.02311332, 0.02250319]),
#   array([0.01559958, 0.01546622, 0.0114623 , 0.01422791]),
#   array([0.01779707, 0.01732277, 0.01743955, 0.01630867]),
#   array([0.01502503, 0.01133297, 0.01362583, 0.01296104]),
#   array([0.02445018, 0.02445007, 0.02386016, 0.02362479]),
#   array([0.02340205, 0.02093739, 0.01956014, 0.01818242]),
#   array([0.02014487, 0.02074741, 0.01802024, 0.02017513]),
#   array([0.0257148 , 0.02674671, 0.02212013, 0.02632837]),
#   array([0.00929232, 0.0085839 , 0.00978881, 0.01003211]),
#   array([0.02232853, 0.02378755, 0.02070766, 0.02109378]),
#   array([0.01833366, 0.01849197, 0.01760831, 0.01980559])]]

# %% [markdown]
# ## Visualizations

# %%
# example = dfs[0]
# cols = ['open', 'high', 'low', 'close']

# for i in range(example.shape[1]):
#     plt.plot(range(example.shape[0]), example.iloc[:,i], label = '{}'.format(example.columns[i]), linewidth = 0.5)
#     plt.legend(bbox_to_anchor=(1.43,1))
#     plt.xlabel("Date")
#     plt.ylabel(names[0])
#     plt.title('{} Versus Predictions'.format(names[0]))
# plt.show()
