# %%
import pandas as pd 
import numpy as np 
import tensorflow as tf 
from tensorflow import keras 
from time import time 
from tensorflow.python.keras.callbacks import TensorBoard 

#believe that these layers are fully connected

# %%
#First Layer - Convolutional Layer 2D
def create_model(): 
    
    #Layers
    input_vals = layers.Input(shape = (192,192,1))
    
    #Encoder 
    x = tf.keras.layers.Conv2D(
        128, #filters
        [6,6],#filter_sz, 
        [2,2], #stride Size, 
        activation = relu,#activation 
        padding = valid)(input_vals)


    #BN 
    x = tf.keras.layers.BatchNormalization(x)

    #Second Layer - MaxPooling 2D
    x = tf.keras.layers.MaxPooling2D(
        [4,4], #pool size, 
        [4,4], #stride size, 
        padding = valid)(x)

    #BN 
    x = tf.keras.layers.BatchNormalization(x)


    #Third Layer - Convolutional Layer 2D 
    x = tf.keras.layers.Conv2D(
        128, #filters
        [6,6],#filter_sz, 
        [2,2], #stride Size, 
        activation = relu,#activation 
        padding = valid)(x)

    #BN 
    x = tf.keras.layers.BatchNormalization(x)

    #Fourth Layer - Maxpooling Layer 
    x = tf.keras.layers.MaxPooling2D(
        [4,4], #pool size, 
        [4,4], #stride size, 
        padding = valid)(x)

    #BN 
    x = tf.keras.layers.BatchNormalization(x)

    #Fifth Layer - Convolutional 2D 
    x = tf.keras.layers.Conv2D(
        128, #filters
        [6,6],#filter_sz, 
        [2,2], #stride Size, 
        activation = relu,#activation 
        padding = valid)(x)

    #BN 
    x = tf.keras.layers.BatchNormalization(x)

    #Sixth Layer - MaxPooling
    x = tf.keras.layers.MaxPooling2D(
        [4,4], #pool size, 
        [4,4], #stride size, 
        padding = valid)(x)

    #BN 
    x = tf.keras.layers.BatchNormalization(x)    

    #Seventh Layer - Convolutional 
    x = tf.keras.layers.Conv2D(
        128, #filters
        [6,6],#filter_sz, 
        [2,2], #stride Size, 
        activation = relu,#activation 
        padding = valid)(x)

    #BN 
    x = tf.keras.layers.BatchNormalization(x)

    #Eight - AveragePooling 2D
    x = tf.keras.layers.AveragePooling2D(
        [4,4], #pool size
        [4,4]) #stride size 
    #Ninth Layer
    x = tf.keras.layers.Conv2D(
        128, #filters
        [6,6],#filter_sz, 
        [2,2], #stride Size, 
        activation = relu,#activation 
        padding = valid)(x)

    #BN 
    x = tf.keras.layers.BatchNormalization(x)

    #Tenth Layer
    x = tf.keras.layers.UpSampling2D([4,4])(x) #upsampling size)(x)

    #BN 
    x = tf.keras.layers.BatchNormalization(x)

    #Eleventh Layer
    x = tf.keras.layers.Conv2D(
        128, #filters
        [6,6],#filter_sz, 
        [2,2], #stride Size, 
        activation = relu,#activation 
        padding = valid)(x)

    #Decoder 
    #BN 
    x = tf.keras.layers.BatchNormalization(x)

    #Twelfth Layer 
    x = tf.keras.layers.UpSampling2D([4,4])(x)

    #BN 
    x = tf.keras.layers.BatchNormalization(x)

    #13th Layer 
    x = tf.keras.layers.Conv2D(
        128, #filters
        [6,6],#filter_sz, 
        [2,2], #stride Size, 
        activation = relu,#activation 
        padding = valid)(x)

    #BN 
    x = tf.keras.layers.BatchNormalization(x)

    #14th Layer 
    x = tf.keras.layers.UpSampling2D([4,4])(x)

    #BN 
    x = tf.keras.layers.BatchNormalization(x)

    #15th Layer 
    x = tf.keras.layers.Conv2D(
        128, #filters
        [6,6],#filter_sz, 
        [2,2], #stride Size, 
        activation = relu,#activation 
        padding = valid)(x)
    #BN 
    x = tf.keras.layers.BatchNormalization(x)

    #16th Layer 
    x = tf.keras.layers.UpSampling2D([4,4])(x)
    #BN 
    x = tf.keras.layers.BatchNormalization(x)

    #17th Layer 
    x = tf.keras.layers.Conv2D(
        128, #filters
        [6,6],#filter_sz, 
        [2,2], #stride Size, 
        activation = relu,#activation 
        padding = valid)(x)

    x = tf.keras.layers.Flatten(x)
    
    cnn_autoencoder = Model(inputs = input_vals, outputs = x)
    return cnn_autoencoder

# %% [markdown]
# # Autoencoder

# %%
create_model().compile(optimizer = "adam", loss = "binary_crossentropy")
create_model().summary()

tensorboard = TensorBoard(log_dir = 'logs/{}'.format(time()))

# %% [markdown]
# # Fitting

# %%
fit_vals = create_model().fit(
    x = train_data, 
    y = train_data, 
    epochs = 100, 
    batch_size = 256, 
    shuffle = False, 
    validation_data(val_data, val_data)
    callbacks = [tensorboard])

preds = create_model().predict(test_data)
